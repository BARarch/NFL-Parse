# %%
import itemQuery as iq

# %%
link  = 'http://www.giants.com/news-and-blogs/article-1/Quotes-94-McAdoo-Manning-Marshall-Collins-Cockrell/21cb1388-48c1-44b1-821d-082976a0bd56'

# %%
link
# Out:
# 'http://www.giants.com/news-and-blogs/article-1/Quotes-94-McAdoo-Manning-Marshall-Collins-Cockrell/21cb1388-48c1-44b1-821d-082976a0bd56'

# %%
iq.getArticle(link)
# Out:
# '<!DOCTYPE html SYSTEM "about:legacy-compat">\n\n     \n     \n         \n         \n         \n         \n         \n       \n     \n     \n     \n    \n        \n    \n\n\n\n\n\n     \n            \n            \n                    <html xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:nflcs="http://clubs.nfl.com" xmlns="http://www.w3.org/1999/xhtml" xmlns:pas="http://www.nfl.com/2009/pluckApplicationServer">\n\n                \n            \n        <head><META http-equiv="Content-Type" content="text/html; charset=UTF-8"><!--ls:begin[stylesheet]--><style type="text/css">.centerComponents\n{\n  margin:auto;\n  text-align:left;\n}\n\n#element1\n{\n  width:980px;\n}\n\n#element2\n{\n  width:980px;\n  display:inline;\n  float:left;\n}\n\n#c1343468367101\n{\n  width:728px;\n  min-height:90px;\n  height:auto !important;\n  height:90px;\n  margin:5px 0 0 10px;\n  display:inline;\n  float:left;\n  background-color:#FFFFFF;\n}\n\n#c1343468367107\n{\n  width
# ...

# %%
import corpus as cp

# %%
cp.corpusNewArticles()
# Out:
# lastId:4721
# Redirect Caught from http://www.seahawks.com/news/2017/09/01/seahawks-trade-wr-jermaine-kearse-and-second-round-pick-jets-dt-sheldon-richardson
# ARTICLE: Scripts 22     Detected Posts 0
# ARTICLE: Scripts 36     Detected Posts 0
# PANE:    Scripts 36     Detected Posts 0
# ARTICLE: Scripts 30     Detected Posts 0
# PANE:    Scripts 30     Detected Posts 0
# ARTICLE: Scripts 29     Detected Posts 0
# PANE:    Scripts 29     Detected Posts 0
# ARTICLE: Scripts 28     Detected Posts 0
# PANE:    Scripts 28     Detected Posts 0
# ARTICLE: Scripts 35     Detected Posts 0
# PANE:    Scripts 35     Detected Posts 0
# ARTICLE: Scripts 22     Detected Posts 0
# ARTICLE: Scripts 36     Detected Posts 0
# PANE:    Scripts 36     Detected Posts 0
# ARTICLE: Scripts 36     Detected Posts 0
# PANE:    Scripts 36     Detected Posts 0
# ARTICLE: Scripts 37     Detected Posts 0
# PANE:    Scripts 37     Detected Posts 0
# ARTICLE: Scripts 35     Detected Posts 0
# ...
