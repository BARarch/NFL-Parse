# %%
import itemQuery as IQ
# %run nfl-parse-demo.py
# Out:
# Name, Major:
# 0, http://www.steelers.com/cda-web/rss-module.htm?tagName=News
# 1, http://www.steelers.com/cda-web/rss-module.htm?tagName=Photos
# 2, http://www.steelers.com/cda-web/rss-module.htm?tagName=Videos
# 3, http://www.steelers.com/cda-web/rss-module.htm?tagName=Audio
# 4, http://www.steelers.com/cda-web/rss-module.htm?tagName=Espa%C3%B1ol
# 5, http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News
# 6, http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20Press%20Releases
# 7, http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20Transcripts
# 8, http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20Late%20For%20Work
# 9, http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20John%20Eisenberg
# 10, http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20The%20Caw
# 11, http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20Byrne%20Identity
# 12, http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20Funny%20Pages
# 13, http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=Videos
# 14, http://www.baltimoreravens.com/cda-web/feeds/video/?clubTag=Video%20-%20Ravens%20Productions%20-%20Ravens%20Report
# 15, http://www.baltimoreravens.com/cda-web/feeds/video/?clubTag=Video%20-%20Ravens%20Productions%20-%20Unscripted
# 16, http://www.baltimoreravens.com/cda-web/feeds/video/?clubTag=Video%20-%20Ravens%20Productions%20-%20Wired
# 17, http://www.baltimoreravens.com/cda-web/feeds/photo
# 18, http://www.bengals.com/cda-web/rss-module.htm?tagName=News%20Stories
# 19, http://blogs.bengals.com/category/hobsons-choice/feed/
# 20, http://blogs.bengals.com/category/heard-it-from-hoard/feed/
# 21, http://www.bengals.com/cda-web/feeds/photo/?clubTag=All%20Team%20Photos
# 22, http://www.bengals.com/cda-web/feeds/photo/?clubTag=All%20Cheerleaders%20Photos
# 23, http://www.clevelandbrowns.com/cda-web/rss-module.htm?tagName=News
# 24, http://www.clevelandbrowns.com/cda-web/rss-module.htm?tagName=Audio
# 25, http://www.clevelandbrowns.com/cda-web/rss-module.htm?tagName=Video
# 26, http://www.clevelandbrowns.com/cda-web/rss-module.htm?tagName=Photo
# 27,
# 28, http://www.packers.com/cda-web/rss-module.htm?tagName=News
# 29, http://www.packers.com/cda-web/rss-module.htm?tagName=Videos
# 30, http://www.packers.com/cda-web/rss-module.htm?tagName=Photos
# 31, http://www.packers.com/cda-web/rss-module.htm?tagName=Audio
# 32, http://www.packers.com/cda-web/rss-module.htm?tagName=InsiderInbox
# 33, http://www.packers.com/cda-web/rss-module.htm?tagName=AskVic
# 34, http://www.vikings.com/cda-web/rss-module.htm?tagName=News
# 35, http://www.vikings.com/cda-web/rss-module.htm?tagName=Videos
# 36, http://www.vikings.com/cda-web/rss-module.htm?tagName=Photos
# 37, http://www.vikings.com/cda-web/rss-module.htm?tagName=Audio
# 38, http://www.detroitlions.com/cda-web/rss-module.htm?tagName=Audio
# 39, http://www.detroitlions.com/cda-web/rss-module.htm?tagName=News
# 40, http://www.detroitlions.com/cda-web/rss-module.htm?tagName=Photos
# 41, http://www.detroitlions.com/cda-web/rss-module.htm?tagName=Video
# 42, http://www.detroitlions.com/cda-web/rss-module.htm?tagName=Twentyman
# 43, http://www.houstontexans.com/cda-web/rss-module.htm?tagName=News
# 44, http://www.houstontexans.com/cda-web/rss-module.htm?tagName=Videos
# 45, http://www.titansonline.com/cda-web/rss-module.htm?tagName=Audio
# 46, http://www.titansonline.com/cda-web/rss-module.htm?tagName=Blogs
# 47, http://www.titansonline.com/cda-web/rss-module.htm?tagName=Community
# 48, http://www.titansonline.com/cda-web/rss-module.htm?tagName=Photos
# 49, http://www.titansonline.com/cda-web/rss-module.htm?tagName=Team%20News
# 50, http://www.titansonline.com/cda-web/rss-module.htm?tagName=TeamNews
# 51, http://www.titansonline.com/cda-web/rss-module.htm?tagName=Videos
# 52, http://www.titansonline.com/cda-web/rss-module.htm?tagName=Podcasts
# 53, http://prod.www.jaguars.clubs.nfl.com/cda-web/rss-module.htm?tagName=News
# 54, http://prod.www.jaguars.clubs.nfl.com/cda-web/rss-module.htm?tagName=News%20-%20The%20O-Zone
# 55, http://prod.www.jaguars.clubs.nfl.com/cda-web/rss-module.htm?tagName=News%20-%20Editorials
# 56, http://www.colts.com/cda-web/rss-module.htm?tagName=News
# 57, http://www.colts.com/cda-web/rss-module.htm?tagName=Video
# 58, http://www.colts.com/cda-web/rss-module.htm?tagName=Audio
# 59, http://www.neworleanssaints.com/cda-web/rss-module.htm?tagName=News
# 60, http://www.neworleanssaints.com/cda-web/rss-module.htm?tagName=Photos
# 61, http://www.neworleanssaints.com/cda-web/rss-module.htm?tagName=Videos
# 62, http://www.neworleanssaints.com/cda-web/rss-module.htm?tagName=Audio
# 63, http://www.atlantafalcons.com/cda-web/rss-module.htm?tagName=News
# 64, http://www.atlantafalcons.com/cda-web/rss-module.htm?tagName=Video
# 65, http://www.buccaneers.com/cda-web/rss-module.htm?tagName=News
# 66, http://www.buccaneers.com/cda-web/rss-module.htm?tagName=Videos
# 67, http://www.buccaneers.com/cda-web/feeds/photo
# 68, http://www.buccaneers.com/cda-web/rss-module.htm?tagName=Audio
# 69, http://www.panthers.com/cda-web/rss-module.htm?tagName=Audio
# 70, http://www.panthers.com/cda-web/rss-module.htm?tagName=News
# 71, http://www.panthers.com/cda-web/rss-module.htm?tagName=Photos
# 72, http://www.panthers.com/cda-web/rss-module.htm?tagName=Videos
# 73, http://www.newyorkjets.com/cda-web/rss-module.htm?tagName=News
# 74, http://www.newyorkjets.com/cda-web/rss-module.htm?tagName=Video
# 75, http://www.newyorkjets.com/cda-web/rss-module.htm?tagName=Audio
# 76, http://www.patriots.com/rss/article/mobile/all/News%20-%20Mobile
# 77, http://www.patriots.com/rss/audio
# 78, http://www.patriots.com/rss/video
# 79, http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=News
# 80, http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=Video
# 81, http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=Audio
# 82, http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=Photos
# 83, http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=Espanol
# 84, http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=Mobile
# 85, http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=Draft
# 86, http://www.buffalobills.com/cda-web/rss-module.htm?tagName=LatestHeadlines
# 87, http://blogs.buffalobills.com/feed/
# 88, http://www.buffalobills.com/cda-web/rss-module.htm?tagName=JohnMurphyShow
# 89, http://www.redskins.com/cda-web/rss-module.htm?tagName=News
# 90, http://www.redskins.com/cda-web/rss-module.htm?tagName=Video
# 91, http://www.redskins.com/cda-web/rss-module.htm?tagName=Photos
# 92, http://www.redskins.com/cda-web/rss-module.htm?tagName=Audio
# 93, http://www.redskins.com/cda-web/rss-module.htm?tagName=Blog
# 94, http://www.philadelphiaeagles.com/cda-web/rss-module.htm?tagName=News
# 95, http://www.philadelphiaeagles.com/cda-web/rss-module.htm?tagName=Video
# 96, http://www.philadelphiaeagles.com/cda-web/rss-module.htm?tagName=Photos
# 97, http://www.philadelphiaeagles.com/cda-web/rss-module.htm?tagName=Audio
# 98, http://www.philadelphiaeagles.com/cda-web/rss-module.htm?tagName=News%20-%20Eagles%20All-Access
# 99, http://www.philadelphiaeagles.com/cda-web/rss-module.htm?tagName=Spadaro
# 100, http://www.dallascowboys.com/rss/article
# 101, http://www.dallascowboys.com/rss/video/
# 102, http://www.dallascowboys.com/rss/audio
# 103, http://www.dallascowboys.com/rss/gallery
# 104, http://www.giants.com/cda-web/rss-module.htm?tagName=News
# 105, http://www.giants.com/cda-web/rss-module.htm?tagName=Videos
# 106, http://www.raiders.com/cda-web/rss-module.htm?tagName=News
# 107, http://www.raiders.com/cda-web/rss-module.htm?tagName=Blogs
# 108, http://www.raiders.com/cda-web/rss-module.htm?tagName=Videos
# 109, http://www.raiders.com/cda-web/rss-module.htm?tagName=Photos
# 110, null
# 111, http://www.denverbroncos.com/cda-web/rss-module.htm?tagName=News&view=mobile
# 112, http://www.denverbroncos.com/cda-web/feeds/audio
# 113, http://www.denverbroncos.com/cda-web/feeds/video
# 114, http://www.denverbroncos.com/cda-web/feeds/photo
# 115, http://www.chiefs.com/cda-web/rss-module.htm?tagName=News
# 116, http://www.chiefs.com/cda-web/rss-module.htm?tagName=Videos
# 117, http://www.49ers.com/cda-web/rss-module.htm?tagName=News
# 118, http://www.49ers.com/cda-web/rss-module.htm?tagName=Audio
# 119, http://www.49ers.com/cda-web/rss-module.htm?tagName=Video
# 120, http://www.49ers.com/cda-web/rss-module.htm?tagName=Player%20Columnists
# 121, http://www.49ers.com/cda-web/rss-module.htm?tagName=Insider%20Columnists
# 122, http://www.49ers.com/cda-web/rss-module.htm?tagName=Coach%27s%20Notebook
# 123, http://www.therams.com/cda-web/rss-module.htm?tagName=News
# 124, http://www.therams.com/cda-web/rss-module.htm?tagName=Video
# 125, http://www.seahawks.com/rss/article
# 126, http://www.seahawks.com/rss/gallery
# 127, http://www.seahawks.com/rss/audio
# 128, http://www.seahawks.com/rss/audio
# 129, http://www.seahawks.com/xml/roster
# 130, http://www.azcardinals.com/cda-web/rss-module.htm?tagName=News
# 131, http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Photos
# 132, http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Videos%20-%20AzCardinals.com%20TV
# 133, http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Videos%20-%20Press%20Conferences
# 134, http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Videos%20-%20Game%20Highlights
# 135, http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Videos%20-%20Maximum%20Cardinals
# 136, http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Audio%20-%20In%20the%20Red%20Zone
# 137, http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Audio%20-%20Big%20Red%20Rage
# 138, http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Audio%20-%20Cardinals%20Underground
# 139, http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Espanol%20News
# 140, http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Espanol%20Audio

# %%
IQ.runItems
# Out:
# <function itemQuery.runItems>

# %%
vals
# Out:
# [['0',
#   'Steelers',
#   'News',
#   'http://www.steelers.com/cda-web/rss-module.htm?tagName=News',
#   'Steelers.com'],
#  ['1',
#   'Steelers',
#   'Photos',
#   'http://www.steelers.com/cda-web/rss-module.htm?tagName=Photos',
#   'Steelers.com'],
#  ['2',
#   'Steelers',
#   'Videos',
#   'http://www.steelers.com/cda-web/rss-module.htm?tagName=Videos',
#   'Steelers.com'],
#  ['3',
#   'Steelers',
#   'Audio',
#   'http://www.steelers.com/cda-web/rss-module.htm?tagName=Audio',
#   'Steelers.com'],
#  ['4',
#   'Steelers',
#   'Espanol',
#   'http://www.steelers.com/cda-web/rss-module.htm?tagName=Espa%C3%B1ol',
#   'Steelers.com'],
#  ['5',
#   'Ravens',
#   'All News',
#   'http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News'],
#  ['6',
#   'Ravens',
#   'Press Releases',
#   'http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20Press%20Releases'],
#  ['7',
#   'Ravens',
#   'Transcripts',
#   'http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20Transcripts'],
#  ['8',
#   'Ravens',
#   'Late For Work',
#   'http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20Late%20For%20Work'],
#  ['9',
#   'Ravens',
#   'John Eisenberg',
#   'http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20John%20Eisenberg'],
#  ['10',
#   'Ravens',
#   'The Caw',
#   'http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20The%20Caw'],
#  ['11',
#   'Ravens',
#   'The Burne Identity',
#   'http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20Byrne%20Identity'],
#  ['12',
#   'Ravens',
#   'Funny Pages',
#   'http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=News%20-%20Funny%20Pages'],
#  ['13',
#   'Ravens',
#   'All Videos',
#   'http://www.baltimoreravens.com/cda-web/rss-module.htm?tagName=Videos'],
#  ['14',
#   'Ravens',
#   'Ravens Report',
#   'http://www.baltimoreravens.com/cda-web/feeds/video/?clubTag=Video%20-%20Ravens%20Productions%20-%20Ravens%20Report'],
#  ['15',
#   'Ravens',
#   'Ravens Unscripted',
#   'http://www.baltimoreravens.com/cda-web/feeds/video/?clubTag=Video%20-%20Ravens%20Productions%20-%20Unscripted'],
#  ['16',
#   'Ravens',
#   'Ravesn Wired',
#   'http://www.baltimoreravens.com/cda-web/feeds/video/?clubTag=Video%20-%20Ravens%20Productions%20-%20Wired'],
#  ['17',
#   'Ravens',
#   'All Photos',
#   'http://www.baltimoreravens.com/cda-web/feeds/photo'],
#  ['18',
#   'Bengals',
#   'News Stories',
#   'http://www.bengals.com/cda-web/rss-module.htm?tagName=News%20Stories'],
#  ['19',
#   'Bengals',
#   "Hobson's Choice Blog",
#   'http://blogs.bengals.com/category/hobsons-choice/feed/'],
#  ['20',
#   'Bengals',
#   'Heard it From Hoard Blog',
#   'http://blogs.bengals.com/category/heard-it-from-hoard/feed/'],
#  ['21',
#   'Bengals',
#   'Team Photos',
#   'http://www.bengals.com/cda-web/feeds/photo/?clubTag=All%20Team%20Photos'],
#  ['22',
#   'Bengals',
#   'Cheerleader Photos',
#   'http://www.bengals.com/cda-web/feeds/photo/?clubTag=All%20Cheerleaders%20Photos'],
#  ['23',
#   'Browns',
#   'News',
#   'http://www.clevelandbrowns.com/cda-web/rss-module.htm?tagName=News'],
#  ['24',
#   'Browns',
#   'Audio',
#   'http://www.clevelandbrowns.com/cda-web/rss-module.htm?tagName=Audio'],
#  ['25',
#   'Browns',
#   'Video',
#   'http://www.clevelandbrowns.com/cda-web/rss-module.htm?tagName=Video'],
#  ['26',
#   'Browns',
#   'Photo',
#   'http://www.clevelandbrowns.com/cda-web/rss-module.htm?tagName=Photo'],
#  ['27', 'Bears', '', '', 'chicagobears.com'],
#  ['28',
#   'Packers',
#   'News',
#   'http://www.packers.com/cda-web/rss-module.htm?tagName=News'],
#  ['29',
#   'Packers',
#   'Videos',
#   'http://www.packers.com/cda-web/rss-module.htm?tagName=Videos'],
#  ['30',
#   'Packers',
#   'Photos',
#   'http://www.packers.com/cda-web/rss-module.htm?tagName=Photos'],
#  ['31',
#   'Packers',
#   'Audio',
#   'http://www.packers.com/cda-web/rss-module.htm?tagName=Audio'],
#  ['32',
#   'Packers',
#   'Insiderbox',
#   'http://www.packers.com/cda-web/rss-module.htm?tagName=InsiderInbox'],
#  ['33',
#   'Packers',
#   'AskVic',
#   'http://www.packers.com/cda-web/rss-module.htm?tagName=AskVic'],
#  ['34',
#   'Vikings',
#   'News',
#   'http://www.vikings.com/cda-web/rss-module.htm?tagName=News'],
#  ['35',
#   'Vikings',
#   'Videos',
#   'http://www.vikings.com/cda-web/rss-module.htm?tagName=Videos'],
#  ['36',
#   'Vikings',
#   'Photos',
#   'http://www.vikings.com/cda-web/rss-module.htm?tagName=Photos'],
#  ['37',
#   'Vikings',
#   'Audio',
#   'http://www.vikings.com/cda-web/rss-module.htm?tagName=Audio'],
#  ['38',
#   'Lions',
#   'Audio',
#   'http://www.detroitlions.com/cda-web/rss-module.htm?tagName=Audio'],
#  ['39',
#   'Lions',
#   'News',
#   'http://www.detroitlions.com/cda-web/rss-module.htm?tagName=News'],
#  ['40',
#   'Lions',
#   'Photos',
#   'http://www.detroitlions.com/cda-web/rss-module.htm?tagName=Photos'],
#  ['41',
#   'Lions',
#   'Video',
#   'http://www.detroitlions.com/cda-web/rss-module.htm?tagName=Video'],
#  ['42',
#   'Lions',
#   'Twentyman',
#   'http://www.detroitlions.com/cda-web/rss-module.htm?tagName=Twentyman'],
#  ['43',
#   'Texans',
#   'news',
#   'http://www.houstontexans.com/cda-web/rss-module.htm?tagName=News'],
#  ['44',
#   'Texans',
#   'videos',
#   'http://www.houstontexans.com/cda-web/rss-module.htm?tagName=Videos'],
#  ['45',
#   'Titans',
#   'Audio',
#   'http://www.titansonline.com/cda-web/rss-module.htm?tagName=Audio'],
#  ['46',
#   'Titans',
#   'Blogs',
#   'http://www.titansonline.com/cda-web/rss-module.htm?tagName=Blogs'],
#  ['47',
#   'Titans',
#   'Community',
#   'http://www.titansonline.com/cda-web/rss-module.htm?tagName=Community'],
#  ['48',
#   'Titans',
#   'Photos',
#   'http://www.titansonline.com/cda-web/rss-module.htm?tagName=Photos'],
#  ['49',
#   'Titans',
#   'Team News',
#   'http://www.titansonline.com/cda-web/rss-module.htm?tagName=Team%20News'],
#  ['50',
#   'Titans',
#   'TeamNews',
#   'http://www.titansonline.com/cda-web/rss-module.htm?tagName=TeamNews'],
#  ['51',
#   'Titans',
#   'Videos',
#   'http://www.titansonline.com/cda-web/rss-module.htm?tagName=Videos'],
#  ['52',
#   'Titans',
#   'Podcasts',
#   'http://www.titansonline.com/cda-web/rss-module.htm?tagName=Podcasts'],
#  ['53',
#   'Jaguars',
#   'Latest Content',
#   'http://prod.www.jaguars.clubs.nfl.com/cda-web/rss-module.htm?tagName=News'],
#  ['54',
#   'Jaguars',
#   'O-Zone',
#   'http://prod.www.jaguars.clubs.nfl.com/cda-web/rss-module.htm?tagName=News%20-%20The%20O-Zone'],
#  ['55',
#   'Jaguars',
#   'Editorials',
#   'http://prod.www.jaguars.clubs.nfl.com/cda-web/rss-module.htm?tagName=News%20-%20Editorials'],
#  ['56',
#   'Colts',
#   'News',
#   'http://www.colts.com/cda-web/rss-module.htm?tagName=News'],
#  ['57',
#   'Colts',
#   'Video',
#   'http://www.colts.com/cda-web/rss-module.htm?tagName=Video'],
#  ['58',
#   'Colts',
#   'Audio',
#   'http://www.colts.com/cda-web/rss-module.htm?tagName=Audio'],
#  ['59',
#   'Saints',
#   'News',
#   'http://www.neworleanssaints.com/cda-web/rss-module.htm?tagName=News',
#   'NewOrleansSaints.com'],
#  ['60',
#   'Saints',
#   'Photos',
#   'http://www.neworleanssaints.com/cda-web/rss-module.htm?tagName=Photos',
#   'NewOrleansSaints.com'],
#  ['61',
#   'Saints',
#   'Videos',
#   'http://www.neworleanssaints.com/cda-web/rss-module.htm?tagName=Videos',
#   'NewOrleansSaints.com'],
#  ['62',
#   'Saints',
#   'Audio',
#   'http://www.neworleanssaints.com/cda-web/rss-module.htm?tagName=Audio',
#   'NewOrleansSaints.com'],
#  ['63',
#   'Falcons',
#   'All News',
#   'http://www.atlantafalcons.com/cda-web/rss-module.htm?tagName=News'],
#  ['64',
#   'Falcons',
#   'All Videos',
#   'http://www.atlantafalcons.com/cda-web/rss-module.htm?tagName=Video'],
#  ['65',
#   'Buccaneers',
#   'News',
#   'http://www.buccaneers.com/cda-web/rss-module.htm?tagName=News'],
#  ['66',
#   'Buccaneers',
#   'Videos',
#   'http://www.buccaneers.com/cda-web/rss-module.htm?tagName=Videos'],
#  ['67',
#   'Buccaneers',
#   'Photos',
#   'http://www.buccaneers.com/cda-web/feeds/photo'],
#  ['68',
#   'Buccaneers',
#   'Audio',
#   'http://www.buccaneers.com/cda-web/rss-module.htm?tagName=Audio'],
#  ['69',
#   'Panthers',
#   'Audio',
#   'http://www.panthers.com/cda-web/rss-module.htm?tagName=Audio'],
#  ['70',
#   'Panthers',
#   'News',
#   'http://www.panthers.com/cda-web/rss-module.htm?tagName=News'],
#  ['71',
#   'Panthers',
#   'Photos',
#   'http://www.panthers.com/cda-web/rss-module.htm?tagName=Photos'],
#  ['72',
#   'Panthers',
#   'Videos',
#   'http://www.panthers.com/cda-web/rss-module.htm?tagName=Videos'],
#  ['73',
#   'Jets',
#   'News',
#   'http://www.newyorkjets.com/cda-web/rss-module.htm?tagName=News'],
#  ['74',
#   'Jets',
#   'Video',
#   'http://www.newyorkjets.com/cda-web/rss-module.htm?tagName=Video'],
#  ['75',
#   'Jets',
#   'Audio',
#   'http://www.newyorkjets.com/cda-web/rss-module.htm?tagName=Audio'],
#  ['76',
#   'Patriots',
#   'News',
#   'http://www.patriots.com/rss/article/mobile/all/News%20-%20Mobile'],
#  ['77', 'Patriots', 'Video', 'http://www.patriots.com/rss/audio'],
#  ['78', 'Patriots', 'Audio', 'http://www.patriots.com/rss/video'],
#  ['79',
#   'Dolphins',
#   'News',
#   'http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=News'],
#  ['80',
#   'Dolphins',
#   'Video',
#   'http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=Video'],
#  ['81',
#   'Dolphins',
#   'Audio',
#   'http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=Audio'],
#  ['82',
#   'Dolphins',
#   'Photos',
#   'http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=Photos'],
#  ['83',
#   'Dolphins',
#   'Espanol',
#   'http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=Espanol'],
#  ['84',
#   'Dolphins',
#   'Mobile',
#   'http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=Mobile'],
#  ['85',
#   'Dolphins',
#   'Draft',
#   'http://www.miamidolphins.com/cda-web/rss-module.htm?tagName=Draft'],
#  ['86',
#   'Bills',
#   'Latest Headlines',
#   'http://www.buffalobills.com/cda-web/rss-module.htm?tagName=LatestHeadlines',
#   'Buffalobills.com'],
#  ['87',
#   'Bills',
#   'Inside the Bills Blog',
#   'http://blogs.buffalobills.com/feed/',
#   'Buffalobills.com'],
#  ['88',
#   'Bills',
#   'John Murphy Show',
#   'http://www.buffalobills.com/cda-web/rss-module.htm?tagName=JohnMurphyShow',
#   'Buffalobills.com'],
#  ['89',
#   'Redskins',
#   'News',
#   'http://www.redskins.com/cda-web/rss-module.htm?tagName=News',
#   'Redskins.com'],
#  ['90',
#   'Redskins',
#   'Video',
#   'http://www.redskins.com/cda-web/rss-module.htm?tagName=Video',
#   'Redskins.com'],
#  ['91',
#   'Redskins',
#   'Photos',
#   'http://www.redskins.com/cda-web/rss-module.htm?tagName=Photos',
#   'Redskins.com'],
#  ['92',
#   'Redskins',
#   'Audio',
#   'http://www.redskins.com/cda-web/rss-module.htm?tagName=Audio',
#   'Redskins.com'],
#  ['93',
#   'Redskins',
#   'Blog',
#   'http://www.redskins.com/cda-web/rss-module.htm?tagName=Blog',
#   'Redskins.com'],
#  ['94',
#   'Eagles',
#   'News',
#   'http://www.philadelphiaeagles.com/cda-web/rss-module.htm?tagName=News'],
#  ['95',
#   'Eagles',
#   'Video',
#   'http://www.philadelphiaeagles.com/cda-web/rss-module.htm?tagName=Video'],
#  ['96',
#   'Eagles',
#   'Photos',
#   'http://www.philadelphiaeagles.com/cda-web/rss-module.htm?tagName=Photos'],
#  ['97',
#   'Eagles',
#   'Audio',
#   'http://www.philadelphiaeagles.com/cda-web/rss-module.htm?tagName=Audio'],
#  ['98',
#   'Eagles',
#   'News-Eagles All-Access',
#   'http://www.philadelphiaeagles.com/cda-web/rss-module.htm?tagName=News%20-%20Eagles%20All-Access'],
#  ['99',
#   'Eagles',
#   'Spadaro',
#   'http://www.philadelphiaeagles.com/cda-web/rss-module.htm?tagName=Spadaro'],
#  ['100', 'Cowboys', 'Articles', 'http://www.dallascowboys.com/rss/article'],
#  ['101', 'Cowboys', 'Videos', 'http://www.dallascowboys.com/rss/video/'],
#  ['102', 'Cowboys', 'Audio', 'http://www.dallascowboys.com/rss/audio'],
#  ['103',
#   'Cowboys',
#   'Photo Galleries',
#   'http://www.dallascowboys.com/rss/gallery'],
#  ['104',
#   'Giants',
#   'News',
#   'http://www.giants.com/cda-web/rss-module.htm?tagName=News',
#   'Giants.com'],
#  ['105',
#   'Giants',
#   'Video',
#   'http://www.giants.com/cda-web/rss-module.htm?tagName=Videos',
#   'Giants.com'],
#  ['106',
#   'Raiders',
#   'News',
#   'http://www.raiders.com/cda-web/rss-module.htm?tagName=News'],
#  ['107',
#   'Raiders',
#   'Blogs',
#   'http://www.raiders.com/cda-web/rss-module.htm?tagName=Blogs'],
#  ['108',
#   'Raiders',
#   'Videos',
#   'http://www.raiders.com/cda-web/rss-module.htm?tagName=Videos'],
#  ['109',
#   'Raiders',
#   'Photos',
#   'http://www.raiders.com/cda-web/rss-module.htm?tagName=Photos'],
#  ['110', 'Chargers', 'null', 'null'],
#  ['111',
#   'Broncos',
#   'News',
#   'http://www.denverbroncos.com/cda-web/rss-module.htm?tagName=News&view=mobile',
#   'DenverBroncos.com'],
#  ['112',
#   'Broncos',
#   'Audio',
#   'http://www.denverbroncos.com/cda-web/feeds/audio',
#   'DenverBroncos.com'],
#  ['113',
#   'Broncos',
#   'Video',
#   'http://www.denverbroncos.com/cda-web/feeds/video',
#   'DenverBroncos.com'],
#  ['114',
#   'Broncos',
#   'Photos',
#   'http://www.denverbroncos.com/cda-web/feeds/photo',
#   'DenverBroncos.com'],
#  ['115',
#   'Chiefs',
#   'News',
#   'http://www.chiefs.com/cda-web/rss-module.htm?tagName=News',
#   'kcchiefs.com'],
#  ['116',
#   'Chiefs',
#   'Videos',
#   'http://www.chiefs.com/cda-web/rss-module.htm?tagName=Videos',
#   'kcchiefs.com'],
#  ['117',
#   '49ers',
#   'News',
#   'http://www.49ers.com/cda-web/rss-module.htm?tagName=News',
#   '49ers.com'],
#  ['118',
#   '49ers',
#   'Audio',
#   'http://www.49ers.com/cda-web/rss-module.htm?tagName=Audio',
#   '49ers.com'],
#  ['119',
#   '49ers',
#   'Video',
#   'http://www.49ers.com/cda-web/rss-module.htm?tagName=Video',
#   '49ers.com'],
#  ['120',
#   '49ers',
#   'Player Columnists',
#   'http://www.49ers.com/cda-web/rss-module.htm?tagName=Player%20Columnists',
#   '49ers.com'],
#  ['121',
#   '49ers',
#   'Insider Columnists',
#   'http://www.49ers.com/cda-web/rss-module.htm?tagName=Insider%20Columnists',
#   '49ers.com'],
#  ['122',
#   '49ers',
#   "Coach's Notebook",
#   'http://www.49ers.com/cda-web/rss-module.htm?tagName=Coach%27s%20Notebook',
#   '49ers.com'],
#  ['123',
#   'Rams',
#   'News',
#   'http://www.therams.com/cda-web/rss-module.htm?tagName=News',
#   'therams.com'],
#  ['124',
#   'Rams',
#   'Video',
#   'http://www.therams.com/cda-web/rss-module.htm?tagName=Video',
#   'therams.com'],
#  ['125', 'Seahawks', 'Articles', 'http://www.seahawks.com/rss/article'],
#  ['126', 'Seahawks', 'Photos', 'http://www.seahawks.com/rss/gallery'],
#  ['127', 'Seahawks', 'Audio', 'http://www.seahawks.com/rss/audio'],
#  ['128', 'Seahawks', 'Video', 'http://www.seahawks.com/rss/audio'],
#  ['129', 'Seahawks', 'Roster', 'http://www.seahawks.com/xml/roster'],
#  ['130',
#   'Cardinals',
#   'News',
#   'http://www.azcardinals.com/cda-web/rss-module.htm?tagName=News'],
#  ['131',
#   'Cardinals',
#   'Photos',
#   'http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Photos'],
#  ['132',
#   'Cardinals',
#   'Videos - AzCardinals.com TV',
#   'http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Videos%20-%20AzCardinals.com%20TV'],
#  ['133',
#   'Cardinals',
#   'Videos - Press Conferences',
#   'http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Videos%20-%20Press%20Conferences'],
#  ['134',
#   'Cardinals',
#   'Videos - Game Highlights',
#   'http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Videos%20-%20Game%20Highlights'],
#  ['135',
#   'Cardinals',
#   'Videos - Maximum Cardinals',
#   'http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Videos%20-%20Maximum%20Cardinals'],
#  ['136',
#   'Cardinals',
#   'Audio - In the Red Zone',
#   'http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Audio%20-%20In%20the%20Red%20Zone'],
#  ['137',
#   'Cardinals',
#   'Audio - Big Red Rage',
#   'http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Audio%20-%20Big%20Red%20Rage'],
#  ['138',
#   'Cardinals',
#   'Audio - Cardinals Underground',
#   'http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Audio%20-%20Cardinals%20Underground'],
#  ['139',
#   'Cardinals',
#   'Espanol News',
#   'http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Espanol%20News'],
#  ['140',
#   'Cardinals',
#   'Espanol Audio',
#   'http://www.azcardinals.com/cda-web/rss-module.htm?tagName=Espanol%20Audio']]

# %%
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Encountered a start tag:", tag)
        for attr in attrs:
            print(attr, end= ' ')
        print(' ')

    #def handle_endtag(self, tag):
        #print("Encountered an end tag :", tag)

    #def handle_data(self, data):
        #print("Encountered some data  :", data)

# %%
class twitterWidgetParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Encountered a start tag:", tag)


    def handle_endtag(self, tag):
        print("Encountered an end tag :", tag)

    def handle_data(self, data):
        print("Encountered some data  :", data)

# %%
class articleContentParser(HTMLParser):
    def __init__(self):
        HTMLParser.__init__(self)
        self.articleContent = ''
        self.articleContentDiv = False
        self.script = False
        self.twitterContent = False
        self.divs = 0
    
    def handle_starttag(self, tag, attrs):        
        if tag == 'div':
            if ('class', 'article-content') in attrs:
                self.articleContentDiv = True
                print("ContentOn")
        
        if self.articleContentDiv and tag == 'div':
            self.divs += 1
        
        if tag == 'script':
            self.script = True
            #print("scriptOn")
            
        if tag == 'blockquote':                  
            self.twitterContent = True
            #print("TwitterOn")

    def handle_endtag(self, tag):
        if self.articleContentDiv and tag == 'div':
            self.divs -= 1
            if self.divs == 0:
                self.articleContentDiv = False
                print("ContentOff")
                
        if tag == 'script':
            self.script = False
            #print("scriptOFF")
            
        if tag == 'blockquote':
            self.twitterContent = False
            #print("TwitterOFF")

    def handle_data(self, data):
        #print("Encountered some data  :", data)
        if self.articleContentDiv and not (self.script or self.twitterContent):
            self.articleContent += data
            self.articleContent += ' '
    
    def getContent(self):
        return self.articleContent

# %%
class paneContentParser(HTMLParser):
    def __init__(self):
        HTMLParser.__init__(self)
        self.articleContent = ''
        self.articleContentDiv = False
        self.script = False
        self.twitterContent = False
        self.divs = 0
    
    def handle_starttag(self, tag, attrs):        
        if tag == 'div':
            if ('class', 'pane-content') in attrs:
                self.articleContentDiv = True
                print("PaneOn")
        
        if self.articleContentDiv and tag == 'div':
            self.divs += 1
        
        if tag == 'script':
            self.script = True
            print("scriptOn")
            
        if tag == 'blockquote':                  
            self.twitterContent = True
            self.articleContent += "__BLOCKQUOTE__"
            print("TwitterOn")

    def handle_endtag(self, tag):
        if self.articleContentDiv and tag == 'div':
            self.divs -= 1
            if self.divs == 0:
                self.articleContentDiv = False
                print("PaneOff")
                
        if tag == 'script':
            self.script = False
            print("scriptOFF")
            
        if tag == 'blockquote':
            self.twitterContent = False
            print("TwitterOFF")

    def handle_data(self, data):
        #print("Encountered some data  :", data)
        if self.articleContentDiv and not (self.script or self.twitterContent):
            self.articleContent += data
            self.articleContent += ' '
    
    def getContent(self):
        return self.articleContent

# %%
seaArticleDemo = IQ.getArticle("http://www.seahawks.com/news/2017/08/14/seahawks-react-preseason-victory-over-los-angeles-chargers")

# %%
len(seaArticleDemo)
# Out:
# 172197

# %%
seaArticleContent = IQ.findContent(seaArticleDemo, '<div class="pane-content">')

# %%
len(seaArticleContent)
# Out:
# 3784

# %%
patsArticleDemo = IQ.getArticle("http://www.patriots.com/news/2017/08/15/game-preview-patriots-texans")

# %%
len(patsArticleDemo)
# Out:
# 153206

# %%
patsArticleContent = IQ.findContent(patsArticleDemo, '<div class="pane-content">')

# %%
len(patsArticleContent)
# Out:
# 9162

# %%
articleDemo = IQ.getArticle("http://www.baltimoreravens.com/news/article-1/Late-For-Work-814-Ravens-Cap-Room-Doubled-Trade-Talk-Swirling-Whats-Ozzie-Newsome-up-to-/4181819c-a79f-498c-b067-7b9d457c9e16")

# %%
len(articleDemo)
# Out:
# 126228

# %%
articleContent = IQ.findContent(articleDemo, '<div class="article-content">')

# %%
len(articleContent)
# Out:
# 24844

# %%
parser = paneContentParser()
parser.feed(patsArticleDemo)
# Out:
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# PaneOn
# scriptOn
# scriptOFF
# PaneOff
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF

# %%
parser.getContent()
# Out:
# "\n    \n   \n     NEW ENGLAND PATRIOTS (0-1) at HOUSTON TEXANS (0-1) Saturday, Aug. 19, 2017 at 8:00 p.m. ET. NRG Stadium (71,795) PATRIOTS:   Download Release  |  Roster  |  Depth Chart   |  Watch Games TEXANS:  Opponent Release  |  Roster  |  Depth Chart New England and Houston will square off in a preseason game for the first time since the Texans' inaugural season in 2002. Houston is the only team in the NFL that the Patriots have never played in a preseason game. The Patriots will return to Houston for the first time since their 34-28 overtime victory over the Atlanta Falcons in Super Bowl LI on Feb. 5, 2017. New England and Houston met twice last year and are scheduled to play each other twice again this year. New England scored a decisive 27-0 victory over Houston in a Week 3 Thursday Night matchup at Gillette Stadium on Sept. 27, 2017, and a 34-16 Divisional Playoff win over the Texans at Gillette on Jan. 14, 2017. In addition to their game on Saturday, the Patriots and Texans will also square off in the regular season on Sunday, Sept. 24 in Foxborough.  Read \n SERIES HISTORY The Patriots and Texans will meet in the preseason for the first time. The teams will play in Week 3 when the Texans travel to face the Patriots at Gillette Stadium on Sept. 24. Last season, the Patriots and Texans played two times with New England taking a 27-0 victory on Sept. 22 and then a 34-16 win in the Divisional Playoffs. Both of those games were played at Gillette Stadium. QB  Jacoby Brissett  made his first NFL start in the 2016 regular season meeting. Overall, the Patriots have met Houston nine times and hold an 8-1 advantage since Houston entered the NFL in 2002. The Patriots are 5-0 overall against the Texans when playing at home. New England's only loss against Houston was in the final game of the 2009 regular-season when Houston defeated the Patriots 34-27. The Patriots had already clinched the division prior to that game and  Tom Brady  was relieved for portions of that game by then backup QB Brian Hoyer. Before the Texans joined the league, the Patriots and the Houston Oilers were foes dating back to the days of the American Football League, playing twice a year from 1960-69 and 33 times overall before the Oilers moved to Tennessee following the 1996 season.  Read \n Tale of the Tape \n \n \n 2016 Regular Season \n New England \n Houston \n \n \n Record \n 14-2 \n 9-7 \n \n \n Divisional Standings \n 1st \n 1st \n \n \n Total Yards Gained \n 6,180 \n 5,035 \n \n \n Total Offense (Rank) \n 386.3.0 (4) \n 314.7 (29) \n \n \n Rush Offense \n 117.0 (7) \n 116.2 (8) \n \n \n Pass Offense \n 269.3 (4) \n 198.5.5 (29) \n \n \n Points per Game \n 27.6 (3) \n 17.4 (28t) \n \n \n Total Yards Allowed \n 5,223 \n 4,821 \n \n \n Total Defense (Rank) \n 326.4 (8) \n 301.3 (1) \n \n \n Rush Defense \n 88.6 (3t) \n 99.7 (12) \n \n \n Pass Defense \n 237.9 (12) \n 201.6 (2) \n \n \n Points Allowed/Game \n 15.6 (1) \n 20.5 (11) \n \n \n Possession Avg. \n 31:13 \n 31:20 \n \n \n Sacks Allowed/Yards Lost \n 24/148 \n 32/242 \n \n \n Sacks Made/Yards \n 34/227 \n 31/198 \n \n \n Total Touchdowns Scored \n 51 \n 25 \n \n \n Penalties Against/Yards \n 93/819 \n 87/868 \n \n \n Punts/Avg. \n 72/44.7 \n 72/47.5 \n \n \n Turnover Differential \n +12 (3) \n -7 (26t) \n \n \n BRADY VS. HOUSTON Tom Brady  is 5-1 against Houston in the regular season and 2-0 in the postseason. Connections: Patriots - Texans   Read \n BROADCAST INFORMATION TELEVISION:  This week's game will be broadcast by the Patriots Preseason Television Network and can be seen in every New England state, as well as Alaska and Hawaii. The preseason network's flagship station is  WBZ-TV CBS  in Boston. WBZ-TV's  Dan Roche  provides play-by-play and is joined by former Patriots tight end  Christian Fauria  in the broadcast booth. Former Patriots linebacker  Matt Chatham  will provide sideline analysis along with WBZ-TV's  Steve Burton . Patriots Football Weekly's beat writers  Paul Perillo   ...

# %%
parser = paneContentParser()
parser.feed(seaArticleDemo)
# Out:
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# PaneOn
# scriptOn
# scriptOFF
# PaneOff
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF
# scriptOn
# scriptOFF

# %%
parser.getContent()
# Out:
# '\n    \n   \n     \n    \n\n   \n     \n   \n \n   \n \n In the first preseason game of the 2017 season, four rushing touchdowns and four forced turnovers set the tone in a convincing 48-17 Seahawks victory over the Los Angeles Chargers at the StubHub Center Below, check out how the Seahawks reacted to the win on social media: https://twitter.com/dshead24/status/896933667045384192 https://twitter.com/Oday_Aboushi75/status/896945838160625664 https://twitter.com/DangeRussWilson/status/896947705703825408 https://twitter.com/JustinBritt68/status/896948042049372161 https://twitter.com/GermainX1/status/896950089716912129 https://twitter.com/PeteCarroll/status/896954084246175744 https://twitter.com/Dewey_MAC/status/896957418495549440 https://twitter.com/thec1_/status/896958728238284801 https://twitter.com/tswoopes18/status/896959854840922112 https://twitter.com/prichiejr/status/897014197069819904 https://www.instagram.com/p/BXyUpVFDHGA/ https://www.instagram.com/p/BXyP-zOAWlp/ https://www.instagram.com/p/BXyPFgMD2NB/ https://www.instagram.com/p/BXyGNgGlu0u/   Read    \n   '

# %%
parser = MyHTMLParser()
parser.feed(seaArticleDemo)
# Out:
# Encountered a start tag: html
# ('xmlns:nflcs', 'http://clubs.nfl.com') ('class', 'no-js') ('lang', 'en') ('dir', 'ltr') ('prefix', 'og: http://ogp.me/ns# fb: http://www.facebook.com/2008/fbml c: http://s.opencalais.com/1/pred/ sys: http://s.opencalais.com/1/type/sys/ lid: http://s.opencalais.com/1/type/lid/ cat: http://s.opencalais.com/1/type/cat/ resolved: http://s.opencalais.com/1/type/er/ cgeo: http://s.opencalais.com/1/type/er/Geo/ eventfact: http://s.opencalais.com/1/type/em/r/ entity: http://s.opencalais.com/1/type/em/e/ cld: http://s.opencalais.com/1/linkeddata/pred/ content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product#')
# Encountered a start tag: head
#
# Encountered a start tag: title
#
# Encountered a start tag: meta
# ('charset', 'utf-8')
# Encountered a start tag: meta
# ('http-equiv', 'cleartype') ('content', 'on')
# Encountered a start tag: meta
# ('name', 'MobileOptimized') ('content', 'width')
# Encountered a start tag: link
# ('rel', 'profile') ('href', 'http://www.w3.org/1999/xhtml/vocab')
# Encountered a start tag: meta
# ('name', 'HandheldFriendly') ('content', 'true')
# Encountered a start tag: link
# ('rel', 'apple-touch-icon-precomposed') ('href', 'http://www.seahawks.com/sites/all/themes/custom/seahawks/apple-touch-icon-precomposed-144x144.png') ('sizes', '144x144')
# Encountered a start tag: link
# ('rel', 'apple-touch-icon-precomposed') ('href', 'http://www.seahawks.com/sites/all/themes/custom/seahawks/apple-touch-icon-precomposed-114x114.png') ('sizes', '114x114')
# Encountered a start tag: meta
# ('about', '/author/dom-lewis') ('typeof', 'skos:Concept') ('property', 'rdfs:label skos:prefLabel') ('content', 'Dom Lewis')
# Encountered a start tag: script
#
# Encountered a start tag: link
# ('rel', 'apple-touch-icon-precomposed') ('href', 'http://www.seahawks.com/sites/all/themes/custom/seahawks/apple-touch-icon-precomposed.png')
# Encountered a start tag: link
# ('rel', 'shortcut icon') ('href', 'http://www.seahawks.com/sites/seahawks.com/files/favicon_1.ico') ('type', 'image/vnd.microsoft.icon')
# Encountered a start tag: link
# ('rel', 'apple-touch-icon-precomposed') ('href', 'http://www.seahawks.com/sites/all/themes/custom/seahawks/apple-touch-icon-precomposed-72x72.png') ('sizes', '72x72')
# Encountered a start tag: meta
# ('name', 'description') ('content', 'Check out how the Seahawks reacted to the win on social media.')
# Encountered a start tag: meta
# ('name', 'viewport') ('content', 'width=device-width, initial-scale=1.0, user-scalable=no')
# Encountered a start tag: meta
# ('name', 'generator') ('content', 'Drupal 7 (http://drupal.org)')
# Encountered a start tag: link
# ('rel', 'image_src') ('href', 'http://www.seahawks.com/sites/seahawks.com/files/styles/open_graph__large/public/_article_thumbnails/rm5_9530.jpg?itok=GEAT1eJA&timestamp=1502747134')
# Encountered a start tag: meta
# ('name', 'rights') ('content', '©2017 Seattle Seahawks. All rights reserved. Do not duplicate in any form without permission of the Seattle Seahawks.')
# Encountered a start tag: link
# ('rel', 'canonical') ('href', 'http://www.seahawks.com/news/2017/08/14/seahawks-react-preseason-victory-over-los-angeles-chargers')
# Encountered a start tag: link
# ('rel', 'shortlink') ('href', 'http://www.seahawks.com/node/190521')
# Encountered a start tag: meta
# ('property', 'og:site_name') ('content', 'Seattle Seahawks')
# Encountered a start tag: meta
# ('property', 'og:type') ('content', 'article')
# Encountered a start tag: meta
# ('property', 'og:url') ('content', 'http://www.seahawks.com/news/2017/08/14/seahawks-react-preseason-victory-over-los-angeles-chargers')
# Encountered a start tag: meta
# ('property', 'og:title') ('content', 'Seahawks React To Preseason Victory Over Los Angeles Chargers')
# Encountered a start tag: meta
# ('property', 'og:description') ('content', 'Check out how the Seahawks reacted to the win on social media.')
# Encountered a start tag: meta
# ('property', 'og:updated_time') ('content', '2017-08-14T14:52:04-07:00')
# Encountered a start tag: meta
# ('property', 'og:image') ('content', 'http://www.seahawks.com/sites/seahawks.com/files/styles/open_graph__large/public/_article_thumbnails/rm5_9530.jpg?itok=GEAT1eJA&timestamp=1502747134')
# Encountered a start tag: meta
# ('name', 'twitter:card') ('content', 'summary')
# Encountered a start tag: meta
# ('name', 'twitter:url') ('content', 'http://www.seahawks.com/news/2017/08/14/seahawks-react-preseason-victory-over-los-angeles-chargers')
# Encountered a start tag: meta
# ('name', 'twitter:title') ('content', 'Seahawks React To Preseason Victory Over Los Angeles Chargers')
# Encountered a start tag: meta
# ('name', 'twitter:description') ('content', 'Check out how the Seahawks reacted to the win on social media.')
# Encountered a start tag: meta
# ('name', 'twitter:image:src') ('content', 'http://www.seahawks.com/sites/seahawks.com/files/styles/open_graph__large/public/_article_thumbnails/rm5_9530.jpg?itok=GEAT1eJA&timestamp=1502747134')
# Encountered a start tag: meta
# ('property', 'article:author') ('content', 'Dom Lewis')
# Encountered a start tag: meta
# ('property', 'article:published_time') ('content', '2017-08-14T14:42:28-07:00')
# Encountered a start tag: meta
# ('property', 'article:modified_time') ('content', '2017-08-14T14:52:04-07:00')
# Encountered a start tag: link
# ('type', 'text/css') ('rel', 'stylesheet') ('href', '//www.seahawks.com/sites/seahawks.com/files/advagg_css/css__SJztPeeNT2ZRAtTxCQRZHmzyiN6eDjn9qwX1FixbQ8I__TcDh8I4dbF4sbv8vWdQDjGHsueonOiuJ9heXpT9ScvM__336YPxrRmp-OPljfU2xdg-hwEb5zzeN5zKGhkOjk-vU.css') ('media', 'all')
# Encountered a start tag: link
# ('type', 'text/css') ('rel', 'stylesheet') ('href', '//www.seahawks.com/sites/seahawks.com/files/advagg_css/css__qtnTXW8KuKDIQ6Gvqv4ds7SKOU4El5m26NKTpTtoz44__EkZQAmGoh7fEIr5-6ntdWXAZXiDRgcG4B8UEyjyuZ_0__336YPxrRmp-OPljfU2xdg-hwEb5zzeN5zKGhkOjk-vU.css') ('media', 'all')
# Encountered a start tag: link
# ('type', 'text/css') ('rel', 'stylesheet') ('href', '//www.seahawks.com/sites/seahawks.com/files/advagg_css/css__NSG0sF2pvNVdvMM0nlpLKg4oF7spSOICIc-7IVU7QwY__phxZS2kiJygM1Nq8BpagEuhtCNe-MPMwOvJs8E7zyyo__336YPxrRmp-OPljfU2xdg-hwEb5zzeN5zKGhkOjk-vU.css') ('media', 'all')
# Encountered a start tag: link
# ('type', 'text/css') ('rel', 'stylesheet') ('href', '//www.seahawks.com/sites/seahawks.com/files/advagg_css/css__hNBNma6vx4P3I_6eVJTLRdM8qczLc5nv8gDhI0GLL-s__ORs0kNYO2uMQ35Oez5xR7-g_x65d33J1SrVXFqPjqBo__336YPxrRmp-OPljfU2xdg-hwEb5zzeN5zKGhkOjk-vU.css') ('media', 'all')
# Encountered a start tag: link
# ('type', 'text/css') ('rel', 'stylesheet') ('href', '//www.seahawks.com/sites/seahawks.com/files/advagg_css/css__6oxfSqthGTFsMj4o7rRXNy0lnFho2wh31crXJERg9oY__mKKPYKCAab8JZjcH1pqxxLYVVAcndZE3ln_gL7vLH_0__336YPxrRmp-OPljfU2xdg-hwEb5zzeN5zKGhkOjk-vU.css') ('media', 'all')
# Encountered a start tag: link
# ('type', 'text/css') ('rel', 'stylesheet') ('href', '//www.seahawks.com/sites/seahawks.com/files/advagg_css/css__nLxvqP_LBj_HdfC6vG1BgrrynOyIwZ9waiXW1IwqIkw__lvCmLZYVuOv9IcErhzxreJF7A_ovdovTZDYBlKdPDMY__336YPxrRmp-OPljfU2xdg-hwEb5zzeN5zKGhkOjk-vU.css') ('media', 'all')
# Encountered a start tag: link
# ('type', 'text/css') ('rel', 'stylesheet') ('href', '//www.seahawks.com/sites/seahawks.com/files/advagg_css/css__KKK4R-GQS0Uy6WpLbOZC26RyBUmOSrbQRs27Ph1h8c0__w7pztteuaJw73Ii72pUjwsQ2v_Kesh2FHqgRIVbgHFQ__336YPxrRmp-OPljfU2xdg-hwEb5zzeN5zKGhkOjk-vU.css') ('media', 'all')
# Encountered a start tag: script
# ('src', '//www.seahawks.com/sites/seahawks.com/files/advagg_js/js__wowyl0IsxlF174WbjQ5ciVvdBBoUHE-ssAiHiXCpSbM__WgSZTnISinbZ743oU5z_347uaE-w5ac_YuL2abje3ow__336YPxrRmp-OPljfU2xdg-hwEb5zzeN5zKGhkOjk-vU.js')
# Encountered a start tag: script
# ('src', '//assets.adobedtm.com/d51a64fedd178a47928591706cfcb7e883ce6cca/satelliteLib-1feba925fa2f5fd9827cb94cf8491a996d37ad3c.js')
# Encountered a start tag: script
# ('src', '//www.seahawks.com/sites/seahawks.com/files/advagg_js/js__7Hb5l_h_7M7aTlwfQPGQGwUolFzYKFy0clNqC7Svdeo__uLAItgNVXueKw7RTnZgAAgcGeY4kW1Okij4ivHMS_YM__336YPxrRmp-OPljfU2xdg-hwEb5zzeN5zKGhkOjk-vU.js')
# Encountered a start tag: script
#
# Encountered a start tag: script
# ('src', '//w.sharethis.com/button/buttons.js')
# Encountered a start tag: script
#
# Encountered a start tag: script
# ('src', '//www.seahawks.com/sites/seahawks.com/files/advagg_js/js__3DqGgpvOoPCLOqVFrVtIFOcsgp_p-jMiOcLoyLeNnc0__tyTOtr5qIMhWpl-04iQI5PltGGjP3_y6HT6tgRXHQco__336YPxrRmp-OPljfU2xdg-hwEb5zzeN5zKGhkOjk-vU.js')
# Encountered a start tag: script
#
# Encountered a start tag: script
#
# Encountered a start tag: script
# ('type', 'text/javascript')
# Encountered a start tag: script
# ('src', '//static.chartbeat.com/js/chartbeat_mab.js')
# Encountered a start tag: style
#
# Encountered a start tag: body
# ('class', 'html not-front not-logged-in page-node page-node- page-node-190521 node-type-article background-ad section-news')
# Encountered a start tag: noscript
#
# Encountered a start tag: iframe
# ('src', '//www.googletagmanager.com/ns.html?id=GTM-PKQ5CD') ('height', '0') ('width', '0') ('style', 'display:none;visibility:hidden')
# Encountered a start tag: script
# ('type', 'text/javascript')
# Encountered a start tag: a
# ('href', '#main-content') ('class', 'element-invisible element-focusable')
# Encountered a start tag: div
# ('class', 'gbl-wrp-1')
# Encountered a start tag: div
# ('class', 'gbl-wrp-2')
# Encountered a start tag: div
# ('class', 'gbl-wrp-3')
# Encountered a start tag: div
# ('class', 'gbl-wrp-4')
# Encountered a start tag: div
# ('class', 'gbl-wrp-5')
# Encountered a start tag: script
# ('type', 'text/javascript')
# Encountered a start tag: script
#
# Encountered a start tag: script
#
# Encountered a start tag: div
# ('class', 'l-page') ('id', 'page')
# Encountered a start tag: div
# ('class', 'l-main')
# Encountered a start tag: div
# ('class', 'l-content') ('role', 'main')
# Encountered a start tag: h2
# ('class', 'element-invisible')
# Encountered a start tag: ul
# ('class', 'breadcrumb')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', '/')
# Encountered a start tag: a
# ('id', 'main-content')
# Encountered a start tag: div
# ('class', 'panel-display chevelle clearfix social-bar')
# Encountered a start tag: div
# ('class', 'panel-col-top panel-panel clearfix')
# Encountered a start tag: div
# ('class', 'panel-region-top')
# Encountered a start tag: div
# ('class', 'panel-pane pane-panels-mini pane-header') ('class', 'panel-pane pane-panels-mini pane-header') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: div
# ('class', 'header mini-panel-display clearfix') ('id', 'mini-panel-header')
# Encountered a start tag: div
# ('class', 'panel-inner')
# Encountered a start tag: div
# ('class', 'mobile-toggle panel-region-wrap clearfix')
# Encountered a start tag: div
# ('class', 'panel-pane pane-block pane-mobile-menu-toggle-mobile-menu-toggle') ('class', 'panel-pane pane-block pane-mobile-menu-toggle-mobile-menu-toggle') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: a
# ('id', 'mobile-menu-toggle')
# Encountered a start tag: div
# ('class', 'panel-pane pane-toggle') ('class', 'panel-pane pane-toggle') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: a
# ('href', '#') ('class', 'toggle-content-pane') ('data-selector', '.header .primary-wrapper') ('data-doscroll', '0')
# Encountered a start tag: div
# ('class', 'banner-ads panel-region-wrap clearfix')
# Encountered a start tag: div
# ('class', 'panel-pane pane-block pane-ad-manager-ad-league-728x90') ('class', 'panel-pane pane-block pane-ad-manager-ad-league-728x90') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: div
# ('id', 'ad-manager-ad-ad-league-728x90-0') ('class', 'ad-manager-ad gpt-ads')
# Encountered a start tag: script
# ('type', 'text/javascript')
# Encountered a start tag: div
# ('class', 'panel-pane pane-block pane-ad-manager-ad-default-226x90') ('class', 'panel-pane pane-block pane-ad-manager-ad-default-226x90') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: div
# ('id', 'ad-manager-ad-ad-default-226x90-0') ('class', 'ad-manager-ad gpt-ads campaign-ad-wrapper ad-default-226x90-0-wrapper')
# Encountered a start tag: script
# ('type', 'text/javascript')
# Encountered a start tag: div
# ('class', 'branding panel-region-wrap clearfix')
# Encountered a start tag: div
# ('class', 'panel-pane pane-custom pane-15') ('class', 'panel-pane pane-custom pane-15') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: h1
# ('class', 'site-name')
# Encountered a start tag: a
# ('href', '/')
# Encountered a start tag: div
# ('class', 'search panel-region-wrap clearfix')
# Encountered a start tag: div
# ('class', 'search-inner')
# Encountered a start tag: div
# ('class', 'panel-pane pane-apachesolr-form') ('class', 'panel-pane pane-apachesolr-form') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: form
# ('class', 'apachesolr-panels-search-form') ('action', '/news/2017/08/14/seahawks-react-preseason-victory-over-los-angeles-chargers') ('method', 'post') ('id', 'apachesolr-panels-search-form') ('accept-charset', 'UTF-8')
# Encountered a start tag: div
#
# Encountered a start tag: h2
# ('class', 'element-invisible')
# Encountered a start tag: div
# ('class', 'form-item form-type-textfield form-item-apachesolr-panels-search-form')
# Encountered a start tag: label
# ('class', 'element-invisible') ('for', 'edit-apachesolr-panels-search-form--2')
# Encountered a start tag: input
# ('title', 'Enter the terms you wish to search for.') ('type', 'text') ('id', 'edit-apachesolr-panels-search-form--2') ('name', 'apachesolr_panels_search_form') ('value', '') ('size', '15') ('maxlength', '128') ('class', 'form-text')
# Encountered a start tag: input
# ('type', 'hidden') ('name', 'form_build_id') ('value', 'form-S7I6bO7BKFeMn8T7t5KTF8_20XzI4jpQDN4Cgzz3KUg')
# Encountered a start tag: input
# ('type', 'hidden') ('name', 'form_id') ('value', 'apachesolr_panels_search_form')
# Encountered a start tag: div
# ('class', 'form-actions form-wrapper') ('id', 'edit-actions')
# Encountered a start tag: input
# ('type', 'submit') ('id', 'edit-submit') ('name', 'op') ('value', 'Search') ('class', 'form-submit')
# Encountered a start tag: div
# ('class', 'primary-wrapper clearfix')
# Encountered a start tag: div
# ('class', 'social panel-region-wrap clearfix')
# Encountered a start tag: div
# ('class', 'panel-pane pane-panels-mini pane-social-menu social-media-links') ('class', 'panel-pane pane-panels-mini pane-social-menu social-media-links') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: div
# ('class', 'panel-display panel-1col clearfix') ('id', 'mini-panel-social_menu')
# Encountered a start tag: div
# ('class', 'panel-panel panel-col')
# Encountered a start tag: div
#
# Encountered a start tag: div
# ('class', 'panel-pane pane-menu-tree pane-menu-social-menu') ('class', 'panel-pane pane-menu-tree pane-menu-social-menu') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: div
# ('class', 'menu-block-wrapper menu-block-ctools-menu-social-menu-1 menu-name-menu-social-menu parent-mlid-0 menu-level-1')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-13386 facebook')
# Encountered a start tag: a
# ('href', 'https://www.facebook.com/Seahawks') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13391 twitter')
# Encountered a start tag: a
# ('href', 'http://www.twitter.com/seahawks') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-14061 email')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/about/email-subscriptions')
# Encountered a start tag: li
# ('class', 'last expanded menu-mlid-13401 social-media-links-extra')
# Encountered a start tag: a
# ('href', '/') ('class', 'social-media-links-extra__icon js-social-more')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-13441')
# Encountered a start tag: a
# ('href', '/gameday/apps')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13431')
# Encountered a start tag: a
# ('href', 'http://instagram.com/seahawks')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-13416')
# Encountered a start tag: a
# ('href', 'http://www.pinterest.com/seattleseahawks') ('target', '_blank')
# Encountered a start tag: div
# ('class', 'primary-menu panel-region-wrap clearfix')
# Encountered a start tag: div
# ('class', 'primary-menu-inner')
# Encountered a start tag: div
# ('class', 'panel-pane pane-nflc-page-primary-links') ('class', 'panel-pane pane-nflc-page-primary-links') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: ul
# ('class', 'links primary-links')
# Encountered a start tag: li
# ('class', 'menu-11246 first')
# Encountered a start tag: a
# ('href', '/news') ('class', 'menu-minipanel menu-minipanel-11246')
# Encountered a start tag: ul
# ('class', 'menu-minipanel-panel menu-minipanel-news-menu-mini-panel')
# Encountered a start tag: li
# ('class', 'first odd last')
# Encountered a start tag: div
# ('class', 'panel-flexible panels-flexible-1976 clearfix') ('id', 'mini-panel-news_menu_mini_panel')
# Encountered a start tag: div
# ('class', 'panel-flexible-inside panels-flexible-1976-inside')
# Encountered a start tag: div
# ('class', 'panels-flexible-region panels-flexible-region-1976-center panels-flexible-region-first panels-flexible-region-last')
# Encountered a start tag: div
# ('class', 'inside panels-flexible-region-inside panels-flexible-region-1976-center-inside panels-flexible-region-inside-first panels-flexible-region-inside-last')
# Encountered a start tag: div
# ('class', 'panel-pane pane-block pane-menu-block-2') ('class', 'panel-pane pane-block pane-menu-block-2') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: div
# ('class', 'menu-block-wrapper menu-block-2 menu-name-main-menu parent-mlid-11246 menu-level-1')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first expanded menu-mlid-11996')
# Encountered a start tag: a
# ('href', '/news')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-11356')
# Encountered a start tag: a
# ('href', '/news/articles')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-11361')
# Encountered a start tag: a
# ('href', '/news/press-releases') ('title', '')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-11391')
# Encountered a start tag: a
# ('href', '/team/injuries')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-11396')
# Encountered a start tag: a
# ('href', '/team/transactions')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13496')
# Encountered a start tag: a
# ('href', '/news/community')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13571')
# Encountered a start tag: a
# ('href', '/gameday/apps')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-16296')
# Encountered a start tag: a
# ('href', '/draft')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-15581')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/superbowl/49')
# Encountered a start tag: li
# ('class', 'expanded menu-mlid-13506')
# Encountered a start tag: a
# ('href', '/')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-13536')
# Encountered a start tag: a
# ('href', '/news/fantasy')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-16851')
# Encountered a start tag: a
# ('href', 'http://history.seahawks.com/')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13526')
# Encountered a start tag: a
# ('href', '/news/on-this-date')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-13511')
# Encountered a start tag: a
# ('href', '/news/round-up')
# Encountered a start tag: li
# ('class', 'expanded menu-mlid-13566')
# Encountered a start tag: a
# ('href', 'https://www.facebook.com/Seahawks') ('target', '_blank')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-13581')
# Encountered a start tag: a
# ('href', 'https://www.facebook.com/Seahawks') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13591')
# Encountered a start tag: a
# ('href', 'https://plus.google.com/+Seahawks/posts') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13586')
# Encountered a start tag: a
# ('href', 'http://instagram.com/seahawks') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13596')
# Encountered a start tag: a
# ('href', 'https://www.pinterest.com/seattleseahawks/') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'collapsed menu-mlid-13576')
# Encountered a start tag: a
# ('href', 'https://twitter.com/seahawks') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-17261')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/content/rss-feeds')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-17981')
# Encountered a start tag: a
# ('href', '/about/email-subscriptions')
# Encountered a start tag: li
# ('class', 'last expanded menu-mlid-13541')
# Encountered a start tag: a
# ('href', '/news/contributors')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-16836')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/news/contributors/john-boyle')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13551')
# Encountered a start tag: a
# ('href', '/news/contributors/tony-drovetto')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13556')
# Encountered a start tag: a
# ('href', '/news/press-releases')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-13561')
# Encountered a start tag: a
# ('href', '/news/contributors/guest-contributors')
# Encountered a start tag: li
# ('class', 'menu-11251 ')
# Encountered a start tag: a
# ('href', '/team/roster') ('class', 'menu-minipanel menu-minipanel-11251')
# Encountered a start tag: ul
# ('class', 'menu-minipanel-panel menu-minipanel-team-menu-mini-panel')
# Encountered a start tag: li
# ('class', 'first odd last')
# Encountered a start tag: div
# ('class', 'panel-flexible panels-flexible-1981 clearfix') ('id', 'mini-panel-team_menu_mini_panel')
# Encountered a start tag: div
# ('class', 'panel-flexible-inside panels-flexible-1981-inside')
# Encountered a start tag: div
# ('class', 'panels-flexible-region panels-flexible-region-1981-center panels-flexible-region-first panels-flexible-region-last')
# Encountered a start tag: div
# ('class', 'inside panels-flexible-region-inside panels-flexible-region-1981-center-inside panels-flexible-region-inside-first panels-flexible-region-inside-last')
# Encountered a start tag: div
# ('class', 'panel-pane pane-block pane-menu-block-3') ('class', 'panel-pane pane-block pane-menu-block-3') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: div
# ('class', 'menu-block-wrapper menu-block-3 menu-name-main-menu parent-mlid-11251 menu-level-1')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first expanded menu-mlid-12001')
# Encountered a start tag: a
# ('href', '/team/roster')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-11376')
# Encountered a start tag: a
# ('href', '/team/roster') ('title', '')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-11386')
# Encountered a start tag: a
# ('href', '/team/depth-chart')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13621')
# Encountered a start tag: a
# ('href', '/team/injuries')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-13626')
# Encountered a start tag: a
# ('href', '/team/transactions')
# Encountered a start tag: li
# ('class', 'expanded menu-mlid-13606')
# Encountered a start tag: a
# ('href', '/team/coaches')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-11916')
# Encountered a start tag: a
# ('href', '/team/coaches')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-11421')
# Encountered a start tag: a
# ('href', '/team/physicians')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-11401')
# Encountered a start tag: a
# ('href', '/team/staff')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-15706')
# Encountered a start tag: a
# ('href', '/about/employment')
# Encountered a start tag: li
# ('class', 'expanded menu-mlid-16926')
# Encountered a start tag: a
# ('href', 'http://history.seahawks.com') ('target', '_blank')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-16846')
# Encountered a start tag: a
# ('href', 'http://history.seahawks.com/')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-16931')
# Encountered a start tag: a
# ('href', 'http://history.seahawks.com/roster.asp')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-16936')
# Encountered a start tag: a
# ('href', '/spirit-of-12/history-of-the-12s')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-16981')
# Encountered a start tag: a
# ('href', 'http://yearbook.seahawks.com/')
# Encountered a start tag: li
# ('class', 'expanded menu-mlid-13611')
# Encountered a start tag: a
# ('href', '/team/facilities')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-13636')
# Encountered a start tag: a
# ('href', '/gameday/centurylink-field')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-14131')
# Encountered a start tag: a
# ('href', '/team/facilities/vmac')
# Encountered a start tag: li
# ('class', 'last expanded menu-mlid-13616')
# Encountered a start tag: a
# ('href', '/team/statistics')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-11411')
# Encountered a start tag: a
# ('href', '/team/statistics')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-11406')
# Encountered a start tag: a
# ('href', '/team/standings')
# Encountered a start tag: li
# ('class', 'menu-11256 ')
# Encountered a start tag: a
# ('href', '/videos-photos') ('class', 'menu-minipanel menu-minipanel-11256')
# Encountered a start tag: ul
# ('class', 'menu-minipanel-panel menu-minipanel-videos-photos-menu-mini-panel')
# Encountered a start tag: li
# ('class', 'first odd last')
# Encountered a start tag: div
# ('class', 'panel-flexible panels-flexible-1986 clearfix') ('id', 'mini-panel-videos_photos_menu_mini_panel')
# Encountered a start tag: div
# ('class', 'panel-flexible-inside panels-flexible-1986-inside')
# Encountered a start tag: div
# ('class', 'panels-flexible-region panels-flexible-region-1986-center panels-flexible-region-first panels-flexible-region-last')
# Encountered a start tag: div
# ('class', 'inside panels-flexible-region-inside panels-flexible-region-1986-center-inside panels-flexible-region-inside-first panels-flexible-region-inside-last')
# Encountered a start tag: div
# ('class', 'panel-pane pane-block pane-menu-block-4') ('class', 'panel-pane pane-block pane-menu-block-4') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: div
# ('class', 'menu-block-wrapper menu-block-4 menu-name-main-menu parent-mlid-11256 menu-level-1')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first expanded menu-mlid-11426')
# Encountered a start tag: a
# ('href', '/videos-photos/videos/video')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-21016')
# Encountered a start tag: a
# ('href', '/videos-photos/videos/video')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-21021')
# Encountered a start tag: a
# ('href', '/videos-photos/videos/highlights')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-21026')
# Encountered a start tag: a
# ('href', '/videos-photos/videos/press-conferences')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-21031')
# Encountered a start tag: a
# ('href', '/videos-photos/videos/raible-call-of-the-game')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-21036')
# Encountered a start tag: a
# ('href', '/videos-photos/videos/seahawks-all-access')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-21041')
# Encountered a start tag: a
# ('href', '/videos-photos/videos/seahawks-saturday-night')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-21051')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/videos-photos/videos/sea-gals')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-21046')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/videos-photos/live')
# Encountered a start tag: li
# ('class', 'expanded menu-mlid-15646')
# Encountered a start tag: a
# ('href', '/videos-photos/audio')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-15666')
# Encountered a start tag: a
# ('href', '/videos-photos/audio')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-20971')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/videos-photos/audio/radio-highlights')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-15656')
# Encountered a start tag: a
# ('href', '/videos-photos/audio/radio-interviews')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-20991')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/podcasts')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-20981')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/videos-photos/audio/kickin-it-with-jon-and-greg-podcast')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-20976')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/videos-photos/audio/players-lounge-podcast')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-20986')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/videos-photos/audio/seahawks-insiders-podcast')
# Encountered a start tag: li
# ('class', 'expanded menu-mlid-13656')
# Encountered a start tag: a
# ('href', '/videos-photos/photos')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-11436')
# Encountered a start tag: a
# ('href', '/videos-photos/photos/all-photos')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13706')
# Encountered a start tag: a
# ('href', '/videos-photos/photos/game-action')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13711')
# Encountered a start tag: a
# ('href', '/videos-photos/photos/sea-gals')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13696')
# Encountered a start tag: a
# ('href', '/videos-photos/photos/eye-on-the-hawks')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13701')
# Encountered a start tag: a
# ('href', '/videos-photos/photos/community')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-11461')
# Encountered a start tag: a
# ('href', 'https://seahawks.photos.nfl.com/') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-16896')
# Encountered a start tag: a
# ('href', 'http://instagram.com/seahawks') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'last expanded menu-mlid-13666')
# Encountered a start tag: a
# ('href', 'http://now.nfl.com/') ('target', '_blank')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-13686')
# Encountered a start tag: a
# ('href', 'http://www.pjtra.com/t/RkFGRExLRk1BS0dKR0RBSUlMRUg') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-16921')
# Encountered a start tag: a
# ('href', 'http://www.nfl.com/qs/nflmobile/index.jsp') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13671')
# Encountered a start tag: a
# ('href', 'http://now.nfl.com/') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13676')
# Encountered a start tag: a
# ('href', 'http://www.nfl.com/videos/seattle-seahawks') ('target', '_blank')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-16916')
# Encountered a start tag: a
# ('href', '/gameday/apps')
# Encountered a start tag: li
# ('class', 'menu-11261 ')
# Encountered a start tag: a
# ('href', '/schedule') ('class', 'menu-minipanel menu-minipanel-11261')
# Encountered a start tag: ul
# ('class', 'menu-minipanel-panel menu-minipanel-schedule-menu-mini-panel')
# Encountered a start tag: li
# ('class', 'first odd last')
# Encountered a start tag: div
# ('class', 'panel-flexible panels-flexible-1991 clearfix') ('id', 'mini-panel-schedule_menu_mini_panel')
# Encountered a start tag: div
# ('class', 'panel-flexible-inside panels-flexible-1991-inside')
# Encountered a start tag: div
# ('class', 'panels-flexible-region panels-flexible-region-1991-center panels-flexible-region-first panels-flexible-region-last')
# Encountered a start tag: div
# ('class', 'inside panels-flexible-region-inside panels-flexible-region-1991-center-inside panels-flexible-region-inside-first panels-flexible-region-inside-last')
# Encountered a start tag: div
# ('class', 'panel-pane pane-block pane-menu-block-5') ('class', 'panel-pane pane-block pane-menu-block-5') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: div
# ('class', 'menu-block-wrapper menu-block-5 menu-name-main-menu parent-mlid-11261 menu-level-1')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first expanded menu-mlid-12011')
# Encountered a start tag: a
# ('href', '/schedule')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-11466')
# Encountered a start tag: a
# ('href', '/schedule') ('title', '')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-11471')
# Encountered a start tag: a
# ('href', '/schedule/download')
# Encountered a start tag: li
# ('class', 'last expanded menu-mlid-13741')
# Encountered a start tag: a
# ('href', '/schedule/events-calendar')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-11481')
# Encountered a start tag: a
# ('href', '/proshop')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13746')
# Encountered a start tag: a
# ('href', '/schedule/community-calendar')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-14136')
# Encountered a start tag: a
# ('href', '/schedule/events-calendar')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-13751')
# Encountered a start tag: a
# ('href', '/cheerleaders/appearances')
# Encountered a start tag: li
# ('class', 'menu-16841 ')
# Encountered a start tag: a
# ('href', 'http://www.pntra.com/t/RkFHRE1MSkhBS0dKR0RBSUlMRUg')
# Encountered a start tag: li
# ('class', 'menu-11266 ')
# Encountered a start tag: a
# ('href', '/gameday') ('class', 'menu-minipanel menu-minipanel-11266')
# Encountered a start tag: ul
# ('class', 'menu-minipanel-panel menu-minipanel-gameday')
# Encountered a start tag: li
# ('class', 'first odd last')
# Encountered a start tag: div
# ('class', 'panel-flexible panels-flexible-1996 clearfix') ('id', 'mini-panel-gameday')
# Encountered a start tag: div
# ('class', 'panel-flexible-inside panels-flexible-1996-inside')
# Encountered a start tag: div
# ('class', 'panels-flexible-region panels-flexible-region-1996-center panels-flexible-region-first panels-flexible-region-last')
# Encountered a start tag: div
# ('class', 'inside panels-flexible-region-inside panels-flexible-region-1996-center-inside panels-flexible-region-inside-first panels-flexible-region-inside-last')
# Encountered a start tag: div
# ('class', 'panel-pane pane-block pane-menu-block-6') ('class', 'panel-pane pane-block pane-menu-block-6') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: div
# ('class', 'menu-block-wrapper menu-block-6 menu-name-main-menu parent-mlid-11266 menu-level-1')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first expanded menu-mlid-11486')
# Encountered a start tag: a
# ('href', '/gameday')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-17041')
# Encountered a start tag: a
# ('href', '/gameday')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-17031')
# Encountered a start tag: a
# ('href', '/gameday/getting-to-centurylink-field')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-16986')
# Encountered a start tag: a
# ('href', '/gameday/getting-into-the-game')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-17036')
# Encountered a start tag: a
# ('href', '/gameday/maximize-gameday-at-centurylink-field')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13781')
# Encountered a start tag: a
# ('href', '/gameday/stadium-concessions')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-17006')
# Encountered a start tag: a
# ('href', '/gameday/getting-into-the-game/gate-map')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-11511')
# Encountered a start tag: a
# ('href', '/gameday/seating-map')
# Encountered a start tag: li
# ('class', 'expanded menu-mlid-17011')
# Encountered a start tag: a
# ('href', '/gameday/gameday-policies-and-information')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-11536')
# Encountered a start tag: a
# ('href', '/gameday/gameday-policies-and-information')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13776')
# Encountered a start tag: a
# ('href', '/gameday/prohibited-items-and-stadium-bag-policy')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13771')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/gameday/gameday-policies-and-information#code')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-17001')
# Encountered a start tag: a
# ('href', '/gameday/question-and-answer')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-17016')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/gameday/gameday-policies-and-information#alcohol-policy')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-17026')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/gameday/gameday-policies-and-information#disabled-access')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-17021')
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/gameday/gameday-policies-and-information#tailgate-policies')
# Encountered a start tag: li
# ('class', 'expanded menu-mlid-13756')
# Encountered a start tag: a
# ('href', '/gameday/getting-to-centurylink-field')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-11551')
# Encountered a start tag: a
# ('href', '/gameday/getting-to-centurylink-field')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13801')
# Encountered a start tag: a
# ('href', 'http://www.amtrakcascades.com/')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-13786')
# Encountered a start tag: a
# ('href', '/gameday/getting-to-centurylink-field/stadium-map')
# Encountered a start tag: li
# ('class', 'expanded menu-mlid-17196')
# Encountered a start tag: a
# ('href', '/gameday/maximize-gameday-at-centurylink-field')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-21528')
# Encountered a start tag: a
# ('href', '/gameday/maximize-gameday-at-centurylink-field#entertainment')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-17211')
# Encountered a start tag: a
# ('href', '/gameday/touchdown-city')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-17206')
# Encountered a start tag: a
# ('href', '/gameday/taima-the-hawk')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-17201')
# Encountered a start tag: a
# ('href', '/gameday/blitz')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-17216')
# Encountered a start tag: a
# ('href', '/BlueThunder')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-17221')
# Encountered a start tag: a
# ('href', '/cheerleaders')
# Encountered a start tag: li
# ('class', 'last expanded menu-mlid-13766')
# Encountered a start tag: a
# ('href', '/gameday/broadcasting/tv')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-11601')
# Encountered a start tag: a
# ('href', '/gameday/broadcasting/tv')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-11596')
# Encountered a start tag: a
# ('href', '/gameday/broadcasting/radio')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-13811')
# Encountered a start tag: a
# ('href', '/gameday/apps')
# Encountered a start tag: li
# ('class', 'menu-12016')
# Encountered a start tag: a
# ('href', '/spirit-of-12') ('class', 'menu-minipanel menu-minipanel-12016')
# Encountered a start tag: ul
# ('class', 'menu-minipanel-panel menu-minipanel-spirit-of-12-menu-mini-panel')
# Encountered a start tag: li
# ('class', 'first odd last')
# Encountered a start tag: div
# ('class', 'panel-flexible panels-flexible-2001 clearfix') ('id', 'mini-panel-spirit_of_12_menu_mini_panel')
# Encountered a start tag: div
# ('class', 'panel-flexible-inside panels-flexible-2001-inside')
# Encountered a start tag: div
# ('class', 'panels-flexible-region panels-flexible-region-2001-center panels-flexible-region-first panels-flexible-region-last')
# Encountered a start tag: div
# ('class', 'inside panels-flexible-region-inside panels-flexible-region-2001-center-inside panels-flexible-region-inside-first panels-flexible-region-inside-last')
# Encountered a start tag: div
# ('class', 'panel-pane pane-block pane-menu-block-7') ('class', 'panel-pane pane-block pane-menu-block-7') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: div
# ('class', 'menu-block-wrapper menu-block-7 menu-name-main-menu parent-mlid-12016 menu-level-1')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first expanded menu-mlid-11271')
# Encountered a start tag: a
# ('href', '/spirit-of-12/history-of-the-12s')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-14326')
# Encountered a start tag: a
# ('href', '/spirit-of-12')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-12021')
# Encountered a start tag: a
# ('href', '/spirit-of-12/history-of-the-12s')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-12026')
# Encountered a start tag: a
# ('href', '/spirit-of-12/12-flag-raisers')
# Encountered a start tag: li
# ('class', 'expanded menu-mlid-13816')
# Encountered a start tag: a
# ('href', '/spirit-of-12/history-of-the-12s')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-13826')
# Encountered a start tag: a
# ('href', '/promotions')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-13836')
# Encountered a start tag: a
# ('href', '/gameday/apps')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-15011')
# Encountered a start tag: a
# ('href', '/wallpaper')
# Encountered a start tag: li
# ('class', 'last expanded menu-mlid-12031')
# Encountered a start tag: a
# ('href', '/spirit-of-12/tagboards')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-12041')
# Encountered a start tag: a
# ('href', '/spirit-of-12/tagboards/seahawks-salute')
# Encountered a start tag: li
# ('class', 'last leaf menu-mlid-12046')
# Encountered a start tag: a
# ('href', '/spirit-of-12/tagboards/tgibf')
# Encountered a start tag: li
# ('class', 'menu-11276 ')
# Encountered a start tag: a
# ('href', '/tickets') ('class', 'menu-minipanel menu-minipanel-11276')
# Encountered a start tag: ul
# ('class', 'menu-minipanel-panel menu-minipanel-tickets-menu-mini-panel')
# Encountered a start tag: li
# ('class', 'first odd last')
# Encountered a start tag: div
# ('class', 'panel-flexible panels-flexible-2006 clearfix') ('id', 'mini-panel-tickets_menu_mini_panel')
# Encountered a start tag: div
# ('class', 'panel-flexible-inside panels-flexible-2006-inside')
# Encountered a start tag: div
# ('class', 'panels-flexible-region panels-flexible-region-2006-center panels-flexible-region-first panels-flexible-region-last')
# Encountered a start tag: div
# ('class', 'inside panels-flexible-region-inside panels-flexible-region-2006-center-inside panels-flexible-region-inside-first panels-flexible-region-inside-last')
# Encountered a start tag: div
# ('class', 'panel-pane pane-block pane-menu-block-8') ('class', 'panel-pane pane-block pane-menu-block-8') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: div
# ('class', 'menu-block-wrapper menu-block-8 menu-name-main-menu parent-mlid-11276 menu-level-1')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first expanded menu-mlid-13841')
# Encountered a start tag: a
# ('href', '/tickets/season-tickets/blue-pride')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'first leaf menu-mlid-13866')
# Encountered a start tag: a
# ('href', '/tickets/single-game-tickets')
# Encountered a start tag: li
# ('class', 'leaf menu-mlid-14141')
# ...
# Encountered a start tag: div
# ('class', 'image-fpp image-fpp-302936')
# Encountered a start tag: figure
# ('class', 'fieldable-panels-pane embedded_photo width-100') ('class', 'fieldable-panels-pane embedded_photo width-100')
# Encountered a start tag: div
# ('class', 'field field--name-field-embedded-photo field--type-image field--label-hidden')
# Encountered a start tag: div
# ('class', 'field__items')
# Encountered a start tag: div
# ('class', 'field__item even')
# Encountered a start tag: img
# ('class', 'borealis image-style-no_limit borealis-js') ('data-borealis-respondsmall', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondsmall/public/toyota-logo_0.png?itok=zFFVNEkw&timestamp=0') ('data-borealis-respondmedium', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondmedium/public/toyota-logo_0.png?itok=BInjDdrj&timestamp=0') ('data-borealis-respondlarge', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondlarge/public/toyota-logo_0.png?itok=YmUyq24X&timestamp=0') ('data-borealis-respondxl', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondxl/public/toyota-logo_0.png?itok=q72gFWp1&timestamp=0') ('data-borealis-respondxl2', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondxl2/public/toyota-logo_0.png?itok=AuU9t4Ku&timestamp=0') ('data-borealis-respondxl3', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondxl3/public/toyota-logo_0.png?itok=j00bHgQn&timestamp=0') ('data-borealis-respondxl4', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondxl4/public/toyota-logo_0.png?itok=NzJphdkB&timestamp=0') ('typeof', 'foaf:Image') ('src', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondsmall/public/toyota-logo_0.png?itok=zFFVNEkw&timestamp=0')
# Encountered a start tag: div
# ('class', 'image-fpp image-fpp-249076')
# Encountered a start tag: figure
# ('class', 'fieldable-panels-pane embedded_photo width-100') ('class', 'fieldable-panels-pane embedded_photo width-100')
# Encountered a start tag: div
# ('class', 'field field--name-field-embedded-photo field--type-image field--label-hidden')
# Encountered a start tag: div
# ('class', 'field__items')
# Encountered a start tag: div
# ('class', 'field__item even')
# Encountered a start tag: img
# ('class', 'borealis image-style-no_limit borealis-js') ('data-borealis-respondsmall', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondsmall/public/embedded-photos/verizon_70_1c_cmyk_r.png?itok=CvENWtoV&timestamp=0') ('data-borealis-respondmedium', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondmedium/public/embedded-photos/verizon_70_1c_cmyk_r.png?itok=_pG5P1j7&timestamp=0') ('data-borealis-respondlarge', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondlarge/public/embedded-photos/verizon_70_1c_cmyk_r.png?itok=JQqCGDG3&timestamp=0') ('data-borealis-respondxl', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondxl/public/embedded-photos/verizon_70_1c_cmyk_r.png?itok=OWLxieTQ&timestamp=0') ('data-borealis-respondxl2', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondxl2/public/embedded-photos/verizon_70_1c_cmyk_r.png?itok=Dadmqde0&timestamp=0') ('data-borealis-respondxl3', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondxl3/public/embedded-photos/verizon_70_1c_cmyk_r.png?itok=qlh_efvz&timestamp=0') ('data-borealis-respondxl4', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondxl4/public/embedded-photos/verizon_70_1c_cmyk_r.png?itok=AJqWSII1&timestamp=0') ('typeof', 'foaf:Image') ('src', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondsmall/public/embedded-photos/verizon_70_1c_cmyk_r.png?itok=CvENWtoV&timestamp=0')
# Encountered a start tag: span
# ('class', 'footer-logo-latest')
# Encountered a start tag: div
# ('class', 'image-fpp image-fpp-169266')
# Encountered a start tag: figure
# ('class', 'fieldable-panels-pane embedded_photo width-100') ('class', 'fieldable-panels-pane embedded_photo width-100')
# Encountered a start tag: div
# ('class', 'field field--name-field-embedded-photo field--type-image field--label-hidden')
# Encountered a start tag: div
# ('class', 'field__items')
# Encountered a start tag: div
# ('class', 'field__item even')
# Encountered a start tag: img
# ('class', 'borealis image-style-no_limit borealis-js') ('data-borealis-respondsmall', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondsmall/public/embedded-photos/vm_footer.png?itok=quXUS1LQ&timestamp=0') ('data-borealis-respondmedium', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondmedium/public/embedded-photos/vm_footer.png?itok=cVZ-ST_p&timestamp=0') ('data-borealis-respondlarge', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondlarge/public/embedded-photos/vm_footer.png?itok=f07BSylM&timestamp=0') ('data-borealis-respondxl', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondxl/public/embedded-photos/vm_footer.png?itok=cFX4JrUY&timestamp=0') ('data-borealis-respondxl2', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondxl2/public/embedded-photos/vm_footer.png?itok=QuE0mI0D&timestamp=0') ('data-borealis-respondxl3', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondxl3/public/embedded-photos/vm_footer.png?itok=ULH700Dc&timestamp=0') ('data-borealis-respondxl4', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondxl4/public/embedded-photos/vm_footer.png?itok=mfIhvp1L&timestamp=0') ('typeof', 'foaf:Image') ('src', 'http://www.seahawks.com/sites/seahawks.com/files/styles/borealis_no_limit_respondsmall/public/embedded-photos/vm_footer.png?itok=quXUS1LQ&timestamp=0')
# Encountered a start tag: div
# ('class', 'panel-pane pane-custom pane-8') ('class', 'panel-pane pane-custom pane-8') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: p
#
# Encountered a start tag: p
#
# Encountered a start tag: div
# ('class', 'footer-main clearfix')
# Encountered a start tag: div
# ('class', 'footer-nfl clearfix')
# Encountered a start tag: div
# ('class', 'footer-toggle-region clearfix')
# Encountered a start tag: div
# ('class', 'footer-toggle panel-region clearfix')
# Encountered a start tag: div
# ('class', 'panel-pane pane-toggle') ('class', 'panel-pane pane-toggle') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: a
# ('href', '#') ('class', 'toggle-content-pane') ('data-selector', '.footer .footer-nfl-inner') ('data-doscroll', '1')
# Encountered a start tag: div
# ('class', 'footer-nfl-inner clearfix')
# Encountered a start tag: div
# ('class', 'nfl-links panel-region clearfix')
# Encountered a start tag: div
# ('class', 'panel-pane pane-custom pane-10') ('class', 'panel-pane pane-custom pane-10') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'https://www.nfl.com') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://nflrush.com/?campaign=NFL_footer') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://nflplayers.com') ('target', '_blank')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.ticketexchangebyticketmaster.com/nfl?intcmp=tm105445&wt.mc_id=NFL_LEAGUE_TE_FOOTER') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.nflyouthpd.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://profootballhof.com') ('target', '_blank')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.nflshop.com/entry.point?target=z&source=NFL_SHOP_TAB_BOTTOM_BANNER') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.nflauction.nfl.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.nfl.com/nflnetwork') ('target', '_blank')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'https://nflonlocation.com/?utm_campaign=OLE&utm_medium=referral&utm_source=nfl&utm_content=footerlink_teamsites') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.jointheteam.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.nflhealthandsafety.com/') ('target', '_blank')
# Encountered a start tag: div
# ('class', 'nfl-teams-american panel-region clearfix')
# Encountered a start tag: div
# ('class', 'nfl-teams-american-inner clearfix')
# Encountered a start tag: div
# ('class', 'panel-pane pane-custom pane-11') ('class', 'panel-pane pane-custom pane-11') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'location')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.buffalobills.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.miamidolphins.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.patriots.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.newyorkjets.com/') ('target', '_blank')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'location')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.baltimoreravens.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.bengals.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.clevelandbrowns.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.steelers.com/') ('target', '_blank')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'location')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.houstontexans.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.colts.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.jaguars.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.titansonline.com/') ('target', '_blank')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'location')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.denverbroncos.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.kcchiefs.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.raiders.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.chargers.com/') ('target', '_blank')
# Encountered a start tag: div
# ('class', 'nfl-teams-national panel-region clearfix')
# Encountered a start tag: div
# ('class', 'nfl-teams-national-inner clearfix')
# Encountered a start tag: div
# ('class', 'panel-pane pane-custom pane-12') ('class', 'panel-pane pane-custom pane-12') ('data-eq-pts', 'pane-base: 1, pane-xs: 300, pane-sm: 450, pane-md: 570, pane-lg: 720, pane-xl: 860, pane-xxl: 980')
# Encountered a start tag: div
# ('class', 'panel-pane-content')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'location')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.dallascowboys.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.giants.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.philadelphiaeagles.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.redskins.com/') ('target', '_blank')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'location')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.chicagobears.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.detroitlions.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.packers.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.vikings.com/') ('target', '_blank')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'location')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.atlantafalcons.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.panthers.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.neworleanssaints.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.buccaneers.com/') ('target', '_blank')
# Encountered a start tag: ul
# ('class', 'menu')
# Encountered a start tag: li
# ('class', 'location')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.azcardinals.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.stlouisrams.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.sf49ers.com/') ('target', '_blank')
# Encountered a start tag: li
#
# Encountered a start tag: a
# ('href', 'http://www.seahawks.com/') ('target', '_blank')
# Encountered a start tag: div
# ('id', 'nflc-background')
# Encountered a start tag: div
# ('id', 'ad-manager-ad-ad-default-1x3-skin-0') ('class', 'ad-manager-ad gpt-ads')
# Encountered a start tag: script
# ('type', 'text/javascript')
# Encountered a start tag: script
# ('type', 'text/javascript')
# Encountered a start tag: div
# ('class', 'geo-interstitial interstitial_container modal-window jqmWindow')
# Encountered a start tag: script
# ('src', '//www.seahawks.com/sites/seahawks.com/files/advagg_js/js__qhsqASiBcAYog51s_rwnmbaiMp1k2mQ1KTnVIb-3EVw__0tQHqDEOZVvqZeE2quCrRa9VA4fHpfFqxGWcAZsbsf8__336YPxrRmp-OPljfU2xdg-hwEb5zzeN5zKGhkOjk-vU.js')
# Encountered a start tag: script
#
# Encountered a start tag: script

# %%
seaArticleDemo
# Out:
# '<!DOCTYPE html>\n  <!--[if IEMobile 7]><html xmlns:nflcs="http://clubs.nfl.com" class="no-js ie iem7" lang="en" dir="ltr" prefix="og: http://ogp.me/ns# fb: http://www.facebook.com/2008/fbml c: http://s.opencalais.com/1/pred/ sys: http://s.opencalais.com/1/type/sys/ lid: http://s.opencalais.com/1/type/lid/ cat: http://s.opencalais.com/1/type/cat/ resolved: http://s.opencalais.com/1/type/er/ cgeo: http://s.opencalais.com/1/type/er/Geo/ eventfact: http://s.opencalais.com/1/type/em/r/ entity: http://s.opencalais.com/1/type/em/e/ cld: http://s.opencalais.com/1/linkeddata/pred/ content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product#"><![endif]-->\n  <!--[if lte IE 6]><html xmlns:nflcs="http://clubs.nfl.com" class="no-js ie lt-ie9 lt-ie8 lt-ie7" lang="en" dir="ltr" prefix="og: http://ogp.me/ns# fb: http://www.facebook.com/2008/fbml c: http://s.opencalais.com/1/pred/ sys: http://s.opencalais.com/1/type/sys/ lid: http://s.opencalais.com/1/type/lid/ cat: http://s.opencalais.com/1/type/cat/ resolved: http://s.opencalais.com/1/type/er/ cgeo: http://s.opencalais.com/1/type/er/Geo/ eventfact: http://s.opencalais.com/1/type/em/r/ entity: http://s.opencalais.com/1/type/em/e/ cld: http://s.opencalais.com/1/linkeddata/pred/ content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product#"><![endif]-->\n  <!--[if (IE 7)&(!IEMobile)]><html xmlns:nflcs="http://clubs.nfl.com" class="no-js ie lt-ie9 lt-ie8" lang="en" dir="ltr" prefix="og: http://ogp.me/ns# fb: http://www.facebook.com/2008/fbml c: http://s.opencalais.com/1/pred/ sys: http://s.opencalais.com/1/type/sys/ lid: http://s.opencalais.com/1/type/lid/ cat: http://s.opencalais.com/1/type/cat/ resolved: http://s.opencalais.com/1/type/er/ cgeo: http://s.opencalais.com/1/type/er/Geo/ eventfact: http://s.opencalais.com/1/type/em/r/ entity: http://s.opencalais.com/1/type/em/e/ cld: http://s.opencalais.com/1/linkeddata/pred/ content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product#"><![endif]-->\n  <!--[if IE 8]><html xmlns:nflcs="http://clubs.nfl.com" class="no-js ie lt-ie9" lang="en" dir="ltr" prefix="og: http://ogp.me/ns# fb: http://www.facebook.com/2008/fbml c: http://s.opencalais.com/1/pred/ sys: http://s.opencalais.com/1/type/sys/ lid: http://s.opencalais.com/1/type/lid/ cat: http://s.opencalais.com/1/type/cat/ resolved: http://s.opencalais.com/1/type/er/ cgeo: http://s.opencalais.com/1/type/er/Geo/ eventfact: http://s.opencalais.com/1/type/em/r/ entity: http://s.opencalais.com/1/type/em/e/ cld: http://s.opencalais.com/1/linkeddata/pred/ content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.or ...
