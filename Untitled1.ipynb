# %%
# %run pullFeeds.py
# Out:
# Done
# team: Steelers 0    	0/15
# team: Steelers 1    	0/15
# team: Steelers 2    	0/15
# team: Steelers 3    	0/15
# team: Steelers 4    	0/15
# team: Ravens 5    	0/15
# team: Ravens 6    	0/15
# team: Ravens 7    	0/15
# team: Ravens 8    	0/15
# team: Ravens 9    	0/15
# team: Ravens 10    	0/15
# team: Ravens 11    	0/15
# team: Ravens 12    	0/15
# team: Ravens 13    	0/15
# team: Ravens 14    	0/15
# team: Ravens 15    	0/15
# team: Ravens 16    	0/15
# team: Ravens 17    	0/17
# team: Bengals 18    	0/15
# team: Bengals 19    	0/20
# team: Bengals 20    	0/20
# team: Bengals 21    	0/10
# team: Bengals 22    	0/10
# team: Browns 23    	0/15
# team: Browns 24    	0/237
# team: Browns 25    	0/15
# team: Browns 26    	0/3
# team: Packers 28    	0/15
# team: Packers 29    	0/15
# team: Packers 30    	0/5
# team: Packers 31    	0/15
# team: Packers 32    	0/15
# team: Packers 33    	0/15
# team: Vikings 34    	0/15
# team: Vikings 35    	7/15
# team: Vikings 36    	0/2
# ...

# %%
CLIENT_SECRET_FILE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3bac1cbf38a6> in <module>()
# ----> 1 CLIENT_SECRET_FILE
#
# NameError: name 'CLIENT_SECRET_FILE' is not defined

# %%
# %run pullFeeds.py
# Out:
# Done
# team: Steelers 0    	0/15
# team: Steelers 1    	0/15
# team: Steelers 2    	0/15
# team: Steelers 3    	0/15
# team: Steelers 4    	0/15
# team: Ravens 5    	0/15
# team: Ravens 6    	0/15
# team: Ravens 7    	0/15
# team: Ravens 8    	0/15
# team: Ravens 9    	0/15
# team: Ravens 10    	0/15
# team: Ravens 11    	0/15
# team: Ravens 12    	0/15
# team: Ravens 13    	0/15
# team: Ravens 14    	0/15
# team: Ravens 15    	0/15
# team: Ravens 16    	0/15
# team: Ravens 17    	0/17
# team: Bengals 18    	0/15
# team: Bengals 19    	0/20
# team: Bengals 20    	0/20
# team: Bengals 21    	0/10
# team: Bengals 22    	0/10
# team: Browns 23    	0/15
# team: Browns 24    	0/237
# team: Browns 25    	0/15
# team: Browns 26    	0/3
# team: Packers 28    	0/15
# team: Packers 29    	0/15
# team: Packers 30    	0/5
# team: Packers 31    	0/15
# team: Packers 32    	0/15
# team: Packers 33    	0/15
# team: Vikings 34    	0/15
# team: Vikings 35    	0/15
# team: Vikings 36    	0/2
# ...

# %%
# %run pullFeeds.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\Anthony\scripts\NFL-Data\NFL-Parse\pullFeeds.py in <module>()
#     237
#     238 # Step 1 Load Feed Information
# --> 239 feeds = getFeeds()
#     240
#     241 # Step 2 Pull all feeds from RSS Lins Using feedFram()
#
# C:\Users\Anthony\scripts\NFL-Data\NFL-Parse\pullFeeds.py in getFeeds()
#      21     https://docs.google.com/spreadsheets/d/1DUBb9OG1A1Xs6v2PK9Oislz4384DSu2MzEbH8dK0ad4/edit#gid=0
#      22     """
# ---> 23     credentials = get_credentials()
#      24     http = credentials.authorize(mgs.httplib2.Http())
#      25     discoveryUrl = ('https://sheets.googleapis.com/$discovery/rest?'
#
# C:\Users\Anthony\scripts\NFL-Data\NFL-Parse\modelGS.py in get_credentials()
#      17         Credentials, the obtained credential.
#      18     """
# ---> 19
# ...
